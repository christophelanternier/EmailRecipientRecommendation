# %%
import random
from datetime import datetime, timedelta
import io
import numpy as np
import heapq
import json
import operator
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from stop_words import get_stop_words
import json

import numpy.random as nprnd

stop_words = get_stop_words('english')

# %%
path_to_data = '../data/'

##########################
# load files #                           
##########################

training = pd.read_csv(path_to_data + 'training_set.csv', sep=',', header=0)
#training_info = pd.read_csv(path_to_data + 'training_info.csv', sep=',', header=0)
training_info = pd.read_csv(path_to_data+"training_info2.csv",sep=',', header=0, index_col=0)
test = pd.read_csv(path_to_data + 'test_set.csv', sep=',', header=0)
#test_info = pd.read_csv(path_to_data + 'test_info.csv', sep=',', header=0)
test_info = pd.read_csv(path_to_data+"test_info2.csv",sep=',', header=0, index_col=0)

global sent_to
with io.open('../data/sent_to.json') as json_data:
    sent_to = json.load(json_data)

global received_from
with io.open('../data/received_from.json') as json_data:
    received_from = json.load(json_data)

# %%
# Correct dates and put datetime format
# We do that because we noticed test_set is only composed of email posterior to the ones of train_set. 
# Datetime format allows to simulate posteriority in our train/test split
from datetime import datetime

for row in training_info.sort(['date']).iterrows():
    date = row[1]['date']
    if date[:3] == '000':
        date = '2' + date[1:]
        
    training_info.loc[row[0], 'date'] = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')

for row in test_info.sort(['date']).iterrows():
    date = row[1]['date']
        
    test_info.loc[row[0], 'date'] = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
# Out:
# /Users/christophelanternier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /Users/christophelanternier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %% [markdown]
# ### Functions

# %%
def most_similar_sklearn(array_embedding_sparse, mail_tfidf, n):
    
    similarities = cosine_similarity(array_embedding_sparse, mail_tfidf)
    if int(round(sorted(similarities[:,0], reverse=True)[0])) ==1:
        closest_ids = similarities[:,0].argsort()[::-1][1:]
    else:
        closest_ids = similarities[:,0].argsort()[::-1]
    
    return closest_ids[:n], similarities

def get_sender(query_mid, training):
    for row in training.iterrows():
        mids = row[1]['mids'].split()
        for mid in mids:
            if int(mid) == query_mid:
                sender = row[1]['sender']
                break
    return sender


def get_10_recipients(closest_ids_per_sender, training_info, similarities):
    dic_of_recipients = {}
    #weight = len(closest_ids_per_sender)+1
    for idx in closest_ids_per_sender:
        recipients = training_info.loc[idx,'recipients'].split()
        for recipient in recipients:
            if '@' in recipient:
                dic_of_recipients[recipient] = dic_of_recipients.get(recipient, 0) + similarities[idx][0]
    
    norm = sum(dic_of_recipients.values())
    for k,v in dic_of_recipients.iteritems():
        dic_of_recipients[k] = float(v)/norm
        
    return dic_of_recipients

def get_recency_features(X_train_info_sender, mail_date, n_recency_features):    
    dic_recency = {}
    df_last_sent_emails = X_train_info_sender[X_train_info_sender.date<= mail_date].sort_values(by = 'date', ascending = False)[:n_recency_features]
    for row in df_last_sent_emails.iterrows():
        recipients = row[1]['recipients'].split()
        for recipient in recipients:
            if '@' in recipient:
                dic_recency[recipient] = dic_recency.get(recipient, 0) + 1
    norm = sum(dic_recency.values())
    for k,v in dic_recency.iteritems():
        dic_recency[k] = float(v)/norm
    
    return dic_recency

def mean_ap(suggested_10_recipients, ground_truth):
    MAP = 0
    correct_guess = 0
    for i, suggestion in enumerate(suggested_10_recipients):
        if suggestion in ground_truth:
            correct_guess +=1
            MAP += float(correct_guess)/(i+1)
    MAP = float(MAP)/min(10, len(ground_truth))
    return MAP

def header_address_ressemblance(text, address):
    head = text[:10].lower()
    name = address[:address.index('@')].split('.')
    for n in name:
        if len(n)>2:
            if n in head:
                return True
    return False

def generate_features(mail_tfidf, mail_date, ground_truth, sender, n, n_recency_features, mail_header):
    
    X_train_info_sender = X_train_info[(X_train_info.sender == sender) & (X_train_info.date<mail_date) & (X_train_info.date>(mail_date-timedelta(days = 180)))]
    print X_train_info_sender.shape
    index_sender = X_train_info_sender.index.values
    X_train_info_sender.index = range(X_train_info_sender.shape[0])
    array_embedding_sparse_sender = array_embedding_sparse[index_sender]

    closest_ids_per_sender, similarities = most_similar_sklearn(array_embedding_sparse_sender, mail_tfidf, n)

    dic_recency = get_recency_features(X_train_info_sender, mail_date, n_recency_features)

    dic_of_recipients = get_10_recipients(closest_ids_per_sender, X_train_info_sender, similarities)

    new_features_per_mail = np.zeros((len(dic_of_recipients), 5))
    labels_per_mail = np.zeros((len(dic_of_recipients), 1))
    index = 0
    for k,v in dic_of_recipients.iteritems():
        KNNScore = v
        NSF = sent_to[sender][k]
        NRF = 0
        if sender in received_from.keys():
            NRF = received_from[sender].get(k, 0)

        recency = 0
        if k in dic_recency.keys():
            recency = dic_recency[k]
        
        if ground_truth != None:
            if k in ground_truth:
                labels_per_mail[index, :] = 1
                
        head = 1.0 * header_address_ressemblance(mail_header, k)

        new_features_per_mail[index, :] = [KNNScore, NSF, NRF, recency, head]
        index +=1

    return new_features_per_mail, labels_per_mail, dic_of_recipients

# %% [markdown]
# ## Create Features

# %%
#Declare Global variables:
global X_train_info
global X_test_info
global array_embedding_sparse

# %%
submission = True
training_info = training_info.sort_values(by='date')

if submission:
    # submission procedure
    X_train_info = training_info
    X_test_info = test_info
    
else:
    # test procedure
    split_date=datetime(2001, 8, 25)
    X_train_info = training_info[training_info.date <= split_date]
    #X_test_info = training_info[training_info.date > split_date]
    
    #Randomize selection of test set:
    X_test_info = training_info[training_info.date > split_date]
    mask = nprnd.choice(range(X_test_info.shape[0]), size=1000, replace=False)
    X_test_info.index = range(X_test_info.shape[0])
    X_test_info = X_test_info[X_test_info.index.isin(mask)]

    X_train_info = training_info

# %%
if submission:
    tfidf = TfidfVectorizer(stop_words = stop_words)
    array_embedding_sparse = tfidf.fit_transform(np.concatenate((X_train_info['body'].values,X_test_info['body'].values)))
    array_embedding_sparse = array_embedding_sparse[:X_train_info.shape[0]]
else:
    #With porter stemming:
    #tfidf = TfidfVectorizer(tokenizer= tokenize, stop_words = stop_words)
    #Without stemming:
    tfidf = TfidfVectorizer(stop_words = stop_words)
    array_embedding_sparse = tfidf.fit_transform(X_train_info['body'].values)

# %% [markdown]
# ## Compute New features

# %%
new_features_all = np.zeros((0,5))
labels_all = np.zeros((0,1))

# number of closest neighbors to collect recipients from:
n = 30
n_recency_features = 50

#re-arrange train index
X_train_info.index = range(X_train_info.shape[0])

t_all = datetime.now()
t_100 = datetime.now()

count = 1
query_id = 15000

for query_id in X_train_info.index.values:
    count+=1
    if count%100==0:
        print count
        print datetime.now()-t_100
        t_100 = datetime.now()

    # Get info on considered mail
    mail = X_train_info['body'][query_id]
    mail_tfidf = tfidf.transform([mail])
    mail_date = X_train_info['date'][query_id]
    ground_truth = X_train_info['recipients'][query_id].split()
    sender = X_train_info['sender'][query_id]

    # Compute Features For this email
    new_features_per_mail, labels_per_mail, dic_of_recipients = generate_features(mail_tfidf, mail_date, ground_truth, sender, n, n_recency_features, mail[:10])
    # Add to global features
    new_features_all = np.concatenate((new_features_all, new_features_per_mail))
    labels_all = np.concatenate((labels_all, labels_per_mail))


print "total took:", datetime.now()-t_all
# Out:
# (0, 5)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-b09ee5b98bd1> in <module>()
#      30
#      31     # Compute Features For this email
# ---> 32     new_features_per_mail, labels_per_mail, dic_of_recipients = generate_features(mail_tfidf, mail_date, ground_truth, sender, n, n_recency_features, mail[:10])
#      33     # Add to global features
#      34     new_features_all = np.concatenate((new_features_all, new_features_per_mail))
#
# <ipython-input-175-a436a25a272c> in generate_features(mail_tfidf, mail_date, ground_truth, sender, n, n_recency_features, mail_header)
#      75     array_embedding_sparse_sender = array_embedding_sparse[index_sender]
#      76
# ---> 77     closest_ids_per_sender, similarities = most_similar_sklearn(array_embedding_sparse_sender, mail_tfidf, n)
#      78
#      79     dic_recency = get_recency_features(X_train_info_sender, mail_date, n_recency_features)
#
# <ipython-input-175-a436a25a272c> in most_similar_sklearn(array_embedding_sparse, mail_tfidf, n)
#       1 def most_similar_sklearn(array_embedding_sparse, mail_tfidf, n):
#       2
# ----> 3     similarities = cosine_similarity(array_embedding_sparse, mail_tfidf)
#       4     if int(round(sorted(similarities[:,0], reverse=True)[0])) ==1:
#       5         closest_ids = similarities[:,0].argsort()[::-1][1:]
#
# /Users/christophelanternier/anaconda/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in cosine_similarity(X, Y, dense_output)
#     908     # to avoid recursive import
#     909
# --> 910     X, Y = check_pairwise_arrays(X, Y)
#     911
#     912     X_normalized = normalize(X, copy=True)
#
# /Users/christophelanternier/anaconda/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in check_pairwise_arrays(X, Y, precomputed, dtype)
#     107     else:
#     108         X = check_array(X, accept_sparse='csr', dtype=dtype,
# --> 109                         warn_on_dtype=warn_on_dtype, estimator=estimator)
#     110         Y = check_array(Y, accept_sparse='csr', dtype=dtype,
#     111                         warn_on_dtype=warn_on_dtype, estimator=estimator)
#
# /Users/christophelanternier/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     414                              " minimum of %d is required%s."
#     415                              % (n_samples, shape_repr, ensure_min_samples,
# --> 416                                 context))
#     417
#     418     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 194267)) while a minimum of 1 is required by check_pairwise_arrays.

# %%
t1 = datetime.now()
#np.save('../data/new_features', new_features_all)
#np.save('../data/labels', labels_all)
print datetime.now() - t1
# Out:
# 0:00:00.120710

# %%
new_features_all = np.load('../data/new_features1.npy')
labels_all = np.ravel(np.load('../data/labels1.npy'))

# %% [markdown]
# ## Train Algorithm

# %%
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
import itertools

# %%
t1 = datetime.now()
#SVM = LinearSVC(dual=False)
#SVM.fit(new_features_all, labels_all)

# C parameter: smaller values mean bigger regularization
#LR_parameters = {'n_estimators' : [5, 10, 20, 50, 100], 
#                 'dual': [True, False], 
#                 'penalty' : ['l1', 'l2']}
#LR = LogisticRegression(C=0.01, dual=True, class_weight='balanced', )
#LR.fit(new_features_all, labels_all)

#ABC_parameters = {'n_estimators' : [5, 10, 20, 50, 100], 
#                'algorithm'=['SAMME.R', 'SAMME']}
#ABC = AdaBoostClassifier()
#ABC.fit(new_features_all, labels_all)

RFC_parameters = {'n_estimators' : [10, 50, 100],
                  'class_weight' : [None, 'balanced']}

RFC = RandomForestClassifier(n_estimators=10, class_weight='balanced')
RFC.fit(new_features_all, labels_all)
print datetime.now() - t1
# Out:
# 0:00:36.242552

# %% [markdown]
# ## Test

# %% [markdown]
# Create test features

# %%
n = 30
n_recency_features = 50
#re-arrange train index
X_train_info.index = range(X_train_info.shape[0])
t_all = datetime.now()
t_100 = datetime.now()
results = pd.DataFrame(columns=['recipients'])
results.index.name = 'mid'
all_mean_ap = []
all_ground_truth = []
all_suggestions = []

cross_val_results = {}

RFC_parameters = {'n_estimators' : [5, 10, 20, 50, 100, 200],
                  'class_weight' : [None, 'balanced']}
listOLists = [RFC_parameters['n_estimators'],RFC_parameters['class_weight']]


#for liste in itertools.product(*listOLists):

#C = liste[0]
#penalty = liste[1]
#LR = LogisticRegression(C=C, dual=False, class_weight='balanced',penalty=penalty )
#LR.fit(new_features_all, labels_all)

#n_estimators = liste[0]
#algorithm = liste[1]
#ABC = AdaBoostClassifier(n_estimators=n_estimators, algorithm=algorithm)
#ABC.fit(new_features_all, labels_all)

#n_estimators = liste[0]
#class_weight = liste[1]
#RFC = RandomForestClassifier(n_estimators=n_estimators, class_weight=class_weight)
#RFC.fit(new_features_all, labels_all)
classifier = RFC

count=0
for query_id in X_test_info.index.values:

    count+=1
    if count%100==0:
        print count
        print datetime.now()-t_100
        t_100 = datetime.now()

    mail = X_test_info['body'][query_id]
    mail_tfidf = tfidf.transform([mail])
    mail_date = X_test_info['date'][query_id]
    if submission:
        ground_truth = None
        query_mid = X_test_info['mid'][query_id]
    else:
        ground_truth = X_test_info['recipients'][query_id].split()
    sender = X_test_info['sender'][query_id]

    # Compute Features For this email
    new_features_per_mail, labels_per_mail, dic_of_recipients = generate_features(mail_tfidf, mail_date, ground_truth, sender, n, n_recency_features, mail[:10])

    # Once the features are computed, we can predict the 10 recipients
    order = classifier.predict_proba(new_features_per_mail)[:,1].argsort()[::-1]
    recipients = np.array(dic_of_recipients.keys())
    suggested_10_recipients = recipients[order][:10]

    if submission:
        string_recipients = ''
        for k in suggested_10_recipients:
            string_recipients+=k + ' '
        results.loc[query_mid, 'recipients'] = string_recipients
    else:

        all_suggestions.append(suggested_10_recipients)
        all_ground_truth.append(ground_truth)
        all_mean_ap.append(mean_ap(suggested_10_recipients, ground_truth))

#cross_val_results[liste] = np.mean(all_mean_ap)
#print cross_val_results
print "total took:", datetime.now()-t_all
# Out:
# 100
# 0:00:06.505307
# 200
# 0:00:06.219480
# 300
# 0:00:05.416094
# 400
# 0:00:06.538668
# 500
# 0:00:06.167794
# 600
# 0:00:06.444270
# 700
# 0:00:06.611563
# 800
# 0:00:07.087390
# 900
# 0:00:06.022202
# 1000
# 0:00:05.914330
# total took: 0:01:02.975024

# %%
for i in range(1000):
    print 'GROUND TRUTH: ', all_ground_truth[i]
    print 'SUGGESTION: ', all_suggestions[i]
    print all_mean_ap[i]
    print
# Out:
# GROUND TRUTH:  ['janel.guerrero@enron.com']
# SUGGESTION:  ['janel.guerrero@enron.com' 'tom.hoatson@enron.com'
#  'daniel.allegretti@enron.com' 'sarah.novosel@enron.com'
#  'thane.twiggs@enron.com' 'charles.yeung@enron.com'
#  'richard.shapiro@enron.com' 'm..landwehr@enron.com' 'joe.connor@enron.com'
#  'paul.kaufman@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jcashin@epsa.org', 'mbennett@epsa.org', 'mreddy@epsa.org', 'jgallagher@epsa.org', 'eperrigo@epsa.org', 'jsimon@epsa.org', 'breilley@coral-energy.com']
# SUGGESTION:  ['linda.robertson@enron.com' 'l..nicolay@enron.com' 'tom.briggs@enron.com'
#  'tom.hoatson@enron.com' 'donna.fulton@enron.com' 'thane.twiggs@enron.com'
#  'richard.ingersoll@enron.com' 'paul.kaufman@enron.com'
#  'steve.montovano@enron.com' 'janine.migden@enron.com']
# 0.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['greg.piper@enron.com' 'john.sherriff@enron.com' 'lydia.cannon@enron.com'
#  'tana.jones@enron.com' 'angie.collins@enron.com' 'andy.zipper@enron.com'
#  'cathy.phillips@enron.com' 'sally.beck@enron.com'
#  'george.mcclellan@enron.com' 'daniel.reck@enron.com']
# 0.0
#
# GROUND TRUTH:  ['jerry.graves@enron.com']
# SUGGESTION:  ['jerry.graves@enron.com' 'shelley.corman@enron.com'
#  'arnie.bailey@enron.com' 'rick.craig@enron.com'
#  'controllers.dl-ets@enron.com' 'lynn.blair@enron.com'
#  'earl.chanley@enron.com' 'greg.mcilwain@enron.com'
#  'david.roensch@enron.com' 'laura.kunkel@enron.com']
# 1.0
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'ginger.dernehl@enron.com'
#  'sarah.novosel@enron.com' 'm..landwehr@enron.com'
#  'james.d.steffes@enron.com' 'darran.binns@enron.com'
#  'gloria.ogenyi@enron.com' 'susan.lindberg@enron.com'
#  'john.shelk@enron.com' 'lara.leibman@enron.com']
# 1.0
#
# GROUND TRUTH:  ['k..heathman@enron.com', 'araceli.romero@enron.com', 'rick.buy@enron.com', 'vladimir.gorny@enron.com', 'rod.hayslett@enron.com', 'mary.trosper@enron.com', 'kathy.campos@enron.com', 'peggy.fowler@enron.com']
# SUGGESTION:  ['kathy.campos@enron.com' 'peggy.fowler@enron.com' 'rod.hayslett@enron.com'
#  'phil.lowry@enron.com' 'shelley.corman@enron.com'
#  'danny.mccarty@enron.com' 'dfsintl@swbell.net' 'dana.gibbs@enron.com'
#  'dfs.international@enron.com' 'tgboldig@aol.com']
# 0.375
#
# GROUND TRUTH:  ['jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'barry.tycholiz@enron.com'
#  'gerald.nemec@enron.com' 'phillip.k.ellen@enron.com'
#  'mark.whitt@enron.com' 'keith.holst@enron.com' 'james.d.steffes@enron.com'
#  'pallen@enron.com' 'joe.hartsoe@enron.com' 'eric.ledain@enron.com']
# 1.0
#
# GROUND TRUTH:  ['dan.dietrich@enron.com', 'center.dl-portland@enron.com', 'no.address@enron.com', 'richard.b.sanders@enron.com']
# SUGGESTION:  ['dan.dietrich@enron.com' 'richard.b.sanders@enron.com'
#  'no.address@enron.com' 'center.dl-portland@enron.com'
#  'phillip.platter@enron.com' 'sean.crandall@enron.com'
#  'john.lavorato@enron.com' 'paul.kaufman@enron.com' 'm..driscoll@enron.com'
#  'kathy.axford@enron.com']
# 1.0
#
# GROUND TRUTH:  ['kim.melodick@enron.com']
# SUGGESTION:  ['kim.melodick@enron.com' 'dan.dorland@enron.com'
#  'angela.mcculloch@enron.com' 'clightfield@velaw.com' 'ian.cooke@enron.com'
#  'rosalinda.zermeno@enron.com' 'elena.chilkina@enron.com'
#  'fletcher.j.sturm@enron.com' 'stephanie.sever@enron.com'
#  'confirmations@starwoodhotels.com']
# 1.0
#
# GROUND TRUTH:  ['kimberly.hillis@enron.com']
# SUGGESTION:  ['kimberly.hillis@enron.com' 'jzufferli@home.com' 'wendy.conwell@enron.com'
#  'livia_zufferli@monitor.com' 'angela.mcculloch@enron.com'
#  'nella.cappelletto@enron.com' 'michelle.wells@enron.com'
#  'kathy.reeves@enron.com' 'becky.young@enron.com'
#  'john.postlethwaite@enron.com']
# 1.0
#
# GROUND TRUTH:  ['controllers.dl-ets@enron.com']
# SUGGESTION:  ['controllers.dl-ets@enron.com' 'steven.harris@enron.com'
#  'gina.taylor@enron.com' 'rich.jolly@enron.com' 'bert.hernandez@enron.com'
#  'kimberly.watson@enron.com' 'dale.ratliff@enron.com'
#  'bart.monden@enron.com' 'crandal.hardy@enron.com'
#  'keith.braswell@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jae.black@enron.com']
# SUGGESTION:  ['jae.black@enron.com' 'rika.imai@enron.com' 'rogers.herndon@enron.com'
#  'billy.braddock@enron.com' 'ron.tapscott@enron.com'
#  'daniel.reck@enron.com' 'terri.clynes@enron.com'
#  'mitch.robinson@enron.com' 'warren.prihoda@enron.com' 'mmmigl@aol.com']
# 1.0
#
# GROUND TRUTH:  ['j..noske@enron.com']
# SUGGESTION:  ['j..noske@enron.com' 'richard.shapiro@enron.com' 'hduncan@caem.org'
#  'jason.riley@novoforum.com' 'lisa.jacobson@enron.com'
#  'daniel.allegretti@enron.com' 'charles.yeung@enron.com'
#  'm..landwehr@enron.com' 'rob.bradley@enron.com'
#  'richard.b.sanders@enron.com']
# 1.0
#
# GROUND TRUTH:  ['mcuilla@houston.rr.com']
# SUGGESTION:  ['mcuilla@houston.rr.com' 'martin.cuilla@enron.com'
#  'gary.lamphier@enron.com' 'geoff.storey@enron.com' 'zwharton@dawray.com'
#  'andrew.h.lewis@enron.com' 'kevin.ruscitti@enron.com'
#  'kenneth.shulklapper@enron.com' 'frank.ermis@enron.com'
#  'eric.bass@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jason.williams@enron.com', 'kim.ward@enron.com']
# SUGGESTION:  ['jason.williams@enron.com' 'kim.ward@enron.com'
#  'cindy.richardson@enron.com' 'pinto.leite@enron.com'
#  'bianca.ornelas@enron.com' 'jim.armogida@enron.com'
#  'nicholas.ernst@enron.com' 'sara.shackleton@enron.com'
#  'tracy.ngo@enron.com' 'patrick.mulvany@enron.com']
# 1.0
#
# GROUND TRUTH:  ['kenrcarson@eol.com']
# SUGGESTION:  ['kenrcars@aol.com' 'mcarson@gtemail.net' 'wentapb@phoenix-cement.com'
#  'njme@dynegy.com' 'susan@metronet.com' 'rlmichaelis@hormel.com'
#  'mikef@amerex.com' 'greg.woulfe@enron.com' 'devin.c.hal@us.pwcglobal.com'
#  'chjohnson@hotmail.com']
# 0.0
#
# GROUND TRUTH:  ['sales@varsitychrysler.com']
# SUGGESTION:  ['kim.melodick@enron.com' 'dan.dorland@enron.com'
#  'angela.mcculloch@enron.com' 'keith.holst@enron.com' 'ian.cooke@enron.com'
#  'jordis.blaschke@enron.com' 'elena.chilkina@enron.com'
#  'jose.marquez@enron.com' 'stephanie.sever@enron.com'
#  'confirmations@starwoodhotels.com']
# 0.0
#
# GROUND TRUTH:  ['john.buchanan@enron.com', 'terry.kowalke@enron.com', 'jean.adams@enron.com']
# SUGGESTION:  ['john.buchanan@enron.com' 'terry.kowalke@enron.com' 'jean.adams@enron.com'
#  'randy.janzen@enron.com' 'joe.linhart@enron.com'
#  'steven.january@enron.com' 'lynn.blair@enron.com'
#  'kathy.washington@enron.com' 'sharon.brown@enron.com'
#  'renee.perry@enron.com']
# 1.0
#
# GROUND TRUTH:  ['kimberly.watson@enron.com']
# SUGGESTION:  ['kimberly.watson@enron.com' 'steven.j.kean@enron.com' 'rick.buy@enron.com'
#  'richard.shapiro@enron.com' 'jarnold@enron.com' 'jshankm@enron.com']
# 1.0
#
# GROUND TRUTH:  ['sales@varsitychrysler.com']
# SUGGESTION:  ['sales@varsitychrysler.com' 'sonya.johnson@enron.com'
#  'rod.kennedy@rbcinvestments.com' 'rosalinda.zermeno@enron.com'
#  'elena.chilkina@enron.com' 'dan.dorland@enron.com'
#  'jose.marquez@enron.com' 'angela.mcculloch@enron.com'
#  'confirmations@starwoodhotels.com' 'mirna.moscoso@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com', 'susan.mara@enron.com', 'jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'susan.mara@enron.com' 'no.address@enron.com'
#  'michael.tribolet@enron.com' 'steve.swain@enron.com'
#  'lisa.mellencamp@enron.com' 'dan.leff@enron.com'
#  'harry.kingerski@enron.com' 'j..noske@enron.com' 'vicki.sharp@enron.com']
# 1.0
#
# GROUND TRUTH:  ['gordon.savage@enron.com', 'harry.kingerski@enron.com', 'robert.neustaedter@enron.com', 'james.d.steffes@enron.com', 'steve.swain@enron.com', 'michael.tribolet@enron.com', 'jeff.dasovich@enron.com']
# SUGGESTION:  ['robert.neustaedter@enron.com' 'james.d.steffes@enron.com'
#  'jeff.dasovich@enron.com' 'michael.tribolet@enron.com'
#  'gordon.savage@enron.com' 'harry.kingerski@enron.com'
#  'steve.swain@enron.com' 'vicki.sharp@enron.com' 'j..noske@enron.com'
#  'scott.gahn@enron.com']
# 1.0
#
# GROUND TRUTH:  ['geoff.storey@enron.com']
# SUGGESTION:  ['geoff.storey@enron.com' 'andrew.h.lewis@enron.com' 'zwharton@dawray.com'
#  'gary.lamphier@enron.com' 's.nadalin@deaus.com' 'steven.p.south@enron.com'
#  'tori.kuykendall@enron.com' 'spatters@oracle.com' 'frank.ermis@enron.com'
#  'kenneth.shulklapper@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jklauber@llgm.com']
# SUGGESTION:  ['ray.alvarez@enron.com' 'jeff.dasovich@enron.com'
#  'richard.b.sanders@enron.com' 'michael.tribolet@enron.com'
#  'richard.shapiro@enron.com' 'don.black@enron.com' 'dan.leff@enron.com'
#  'vicki.sharp@enron.com' 'mark.palmer@enron.com' 'paul.kaufman@enron.com']
# 0.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com' 'john.sherriff@enron.com'
#  'matthew.scrimshaw@enron.com' 'peggy.mccurley@enron.com'
#  'philippe.bibi@enron.com' 'brian.stanley@enron.com'
#  'rebecca.mcdonald@enron.com' 'shirley.tijerina@enron.com'
#  'john.lavorato@enron.com' 'richard.shapiro@enron.com']
# 1.0
#
# GROUND TRUTH:  ['robert.frank@enron.com']
# SUGGESTION:  ['robert.frank@enron.com' 'alan.comnes@enron.com' 'kristin.walsh@enron.com'
#  'michael.tribolet@enron.com' 'j..noske@enron.com'
#  'harry.kingerski@enron.com' 'steve.montovano@enron.com'
#  'paul.kaufman@enron.com' 'richard.b.sanders@enron.com'
#  'no.address@enron.com']
# 1.0
#
# GROUND TRUTH:  ['j_perches@yahoo.com']
# SUGGESTION:  ['j_perches@yahoo.com' 'kevin.ruscitti@enron.com' 'greg.martin@enron.com'
#  'hunter.s.shively@enron.com' 'jason.williams@enron.com'
#  'bryant.frihart@enron.com' 'gary.lamphier@enron.com'
#  'tony.harris@enron.com' 'james.simpson@enron.com' 's.nadalin@deaus.com']
# 1.0
#
# GROUND TRUTH:  ['john.lavorato@enron.com', 'louise.kitchen@enron.com']
# SUGGESTION:  ['john.lavorato@enron.com' 'louise.kitchen@enron.com'
#  'rogers.herndon@enron.com' 'robert.benson@enron.com'
#  'doug.gilbert-smith@enron.com' 'james.d.steffes@enron.com'
#  'mike.carson@enron.com' 'rosemarie.balmes@enron.com' 'mary.hain@enron.com'
#  'sarah.novosel@enron.com']
# 1.0
#
# GROUND TRUTH:  ['controllers.dl-ets@enron.com']
# SUGGESTION:  ['controllers.dl-ets@enron.com' 'bert.hernandez@enron.com'
#  'max.brown@enron.com' 'terry.kowalke@enron.com' 'randy.rice@enron.com'
#  'rich.jolly@enron.com' 'rick.craig@enron.com' 'dannis.bellard@enron.com'
#  'dale.ratliff@enron.com' 'keith.braswell@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rick.buy@enron.com']
# SUGGESTION:  ['rick.buy@enron.com' 'beth.apollo@enron.com' 'john.lavorato@enron.com'
#  'greg.piper@enron.com' 'andrew.cornfield@enron.com'
#  'mark.e.taylor@enron.com' 'fernley.dyson@enron.com' 'sally.beck@enron.com'
#  'mike.deville@enron.com' 'joe.gold@enron.com']
# 1.0
#
# GROUND TRUTH:  ['lhayman@skadden.com']
# SUGGESTION:  ['lhayman@skadden.com' 'marie.heard@enron.com' 'n..gray@enron.com'
#  'mcgovernw@sec.gov' 'gordon.hagendorf@kvaerner.com' 'c..koehler@enron.com'
#  'holly.keiser@enron.com' 'mark.greenberg@enron.com'
#  'brent.hendry@enron.com' 'david.cox@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com' 'rebecca.mcdonald@enron.com' 'greg.piper@enron.com'
#  'loretta.brelsford@enron.com' 'e..haedicke@enron.com'
#  'awais.omar@enron.com' 'Sutton@Enron' 'brian.stanley@enron.com'
#  'mark.e.taylor@enron.com' 'creek@apbenergy.com']
# 1.0
#
# GROUND TRUTH:  ['rnichol@firstunion1.com']
# SUGGESTION:  ['susan.bailey@enron.com' 'sara.shackleton@enron.com'
#  'pinto.leite@enron.com' 'keegan.farrell@enron.com'
#  'carolyn.george@enron.com' 'marie.heard@enron.com' 'halnromm@hotmail.com'
#  'travis.mccullough@enron.com' 'esmeralda.gonzalez@enron.com'
#  'samantha.boyd@enron.com']
# 0.0
#
# GROUND TRUTH:  ['rlaird@natsource.ca']
# SUGGESTION:  ['rlaird@natsource.ca' 'alratani@stampede-toyota.com'
#  'lexserv@cadvision.com' 'elena.chilkina@enron.com' 'dan.dorland@enron.com'
#  'jose.marquez@enron.com' 'geoff.storey@enron.com'
#  'confirmations@starwoodhotels.com' 'sales@varsitychrysler.com'
#  'perfmgmt@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rlaird@natsource.ca']
# SUGGESTION:  ['rlaird@natsource.ca' 'ian.cooke@enron.com' 'migeorge@deloitte.ca'
#  'confirmations@starwoodhotels.com' 'sonya.johnson@enron.com'
#  'perfmgmt@enron.com' 'rosalinda.zermeno@enron.com'
#  'jordis.blaschke@enron.com' 'elena.chilkina@enron.com'
#  'dan.dorland@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rlaird@natsource.ca']
# SUGGESTION:  ['rlaird@natsource.ca' 'mike.cowan@enron.com' 'dan.dorland@enron.com'
#  'sales@varsitychrysler.com' 'sonya.johnson@enron.com'
#  'elena.chilkina@enron.com' 'jose.marquez@enron.com'
#  'jfrizzley@shearman.com' 'stephanie.sever@enron.com'
#  'confirmations@starwoodhotels.com']
# 1.0
#
# GROUND TRUTH:  ['controllers.dl-ets@enron.com']
# SUGGESTION:  ['controllers.dl-ets@enron.com' 'kggruhl@duke-energy.com' 'sbreen@czn.com'
#  'steven.january@enron.com']
# 1.0
#
# GROUND TRUTH:  ['msteffes@mindspring.com']
# SUGGESTION:  ['msteffes@mindspring.com' 'steven.j.kean@enron.com'
#  'richard.shapiro@enron.com' 'sue.nord@enron.com'
#  'susan.lindberg@enron.com' 'leslie.lawner@enron.com'
#  'steve.montovano@enron.com' 'linda.robertson@enron.com'
#  'robert.frank@enron.com' 'charles.yeung@enron.com']
# 1.0
#
# GROUND TRUTH:  ['louise.kitchen@enron.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'paul.smith@enron.com' 'c..bland@enron.com'
#  'iris.mack@enron.com' 'john.suarez@enron.com' 'd..baughman@enron.com'
#  'mario.cardoso@enron.com' 'jean.mrha@enron.com' 'billy.lemmons@enron.com'
#  'david.minns@enron.com']
# 1.0
#
# GROUND TRUTH:  ['susan.mara@enron.com', 'scott.gahn@enron.com', 'suzanne.calcagno@enron.com', 'susan.lindberg@enron.com', 'f..smith@enron.com', 'tori.kuykendall@enron.com', 'phillip.k.ellen@enron.com', 'greg.sharp@enron.com', 'donna.greif@enron.com', 'donna.fulton@enron.com', 'ray.alvarez@enron.com', 'l..gay@enron.com', 'mark.courtney@enron.com', 'jess.hewitt@enron.com', 'paul.kaufman@enron.com', 'ed.mcmichael@enron.com', 'richard.b.sanders@enron.com', 'frank.ermis@enron.com', 'james.d.steffes@enron.com', 'richard.shapiro@enron.com', 'don.black@enron.com', 'steven.p.south@enron.com', 'jane.tholt@enron.com', 'robert.frank@enron.com', 'robert.superty@enron.com', 'patti.sullivan@enron.com', 'stephanie.miller@enron.com', 'cathy.pittenger@enron.com', 'alan.comnes@enron.com', 'l..nicolay@enron.com', 'steve.walton@enron.com', 'jeff.dasovich@enron.com', 'lynne.ruffer@enron.com', 'dave.perrino@enron.com', 'kristann.shireman@enron.com', 'roger.ponce@enron.com', 'barry.tycholiz@enron.com', 'jennifer.thome@enron.com']
# SUGGESTION:  ['frank.ermis@enron.com' 'jane.tholt@enron.com' 'don.black@enron.com'
#  'mark.courtney@enron.com' 'tori.kuykendall@enron.com'
#  'stephanie.miller@enron.com' 'jennifer.thome@enron.com'
#  'paul.kaufman@enron.com' 'robert.frank@enron.com'
#  'robert.superty@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jason.williams@enron.com']
# SUGGESTION:  ['joanne.rozycki@enron.com' 'h..douglas@enron.com'
#  'travis.mccullough@enron.com' 'georgi.landau@enron.com'
#  'tracy.ngo@enron.com' 't..hodge@enron.com' 'tom.doukas@enron.com'
#  'tanya.rohauer@enron.com' 'morris.clark@enron.com'
#  'matt.maxwell@enron.com']
# 0.0
#
# GROUND TRUTH:  ['sales@varsitychrysler.com']
# SUGGESTION:  ['dan.dorland@enron.com' 'mike.cowan@enron.com' 'rlaird@natsource.ca'
#  'stephane.brodeur@enron.com' 'sonya.johnson@enron.com'
#  'wayne.mays@enron.com' 'elena.chilkina@enron.com'
#  'kdorland@titanelectric.com' '3toyota@cadvision.com'
#  'jose.marquez@enron.com']
# 0.0
#
# GROUND TRUTH:  ['j..noske@enron.com']
# SUGGESTION:  ['j..noske@enron.com' 'aleck.dadson@enron.com' 'susan.lindberg@enron.com'
#  'susan.mara@enron.com' 'leslie.lawner@enron.com'
#  'lisa.mellencamp@enron.com' 'paul.kaufman@enron.com'
#  'jeff.dasovich@enron.com' 'charles.yeung@enron.com'
#  'richard.shapiro@enron.com']
# 1.0
#
# GROUND TRUTH:  ['louise.kitchen@enron.com', 'savita.puthigai@enron.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'sally.beck@enron.com' 'rex.shelby@enron.com'
#  'mark.e.taylor@enron.com' 'e..haedicke@enron.com'
#  'stephen.abbanat@enron.com' 'philippe.bibi@enron.com'
#  'jeff.skilling@enron.com' 'john.arnold@enron.com' 'j..yanowski@enron.com']
# 0.5
#
# GROUND TRUTH:  ['susan.mara@enron.com', 'kevin.keeney@enron.com', 'lamar.frazier@enron.com', 'karen.denne@enron.com']
# SUGGESTION:  ['lamar.frazier@enron.com' 'susan.mara@enron.com' 'kevin.keeney@enron.com'
#  'karen.denne@enron.com' 'jeremy.blachman@enron.com' 'scott.gahn@enron.com'
#  'paul.kaufman@enron.com' 'jeff.richter@enron.com' 'jbennett@gmssr.com'
#  'c..williams@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jill.chatterton@enron.com']
# SUGGESTION:  ['franksen@enron.com' 'diana.willigerod@enron.com'
#  'jeremy.morris@enron.com' 'diane.cutsforth@enron.com'
#  'anna.mehrer@enron.com' 'res0fkkz@verizon.net' 'jelvig@aol.com'
#  'tjaeckle@jaecklewholesale.com' 'melba.lozano@enron.com'
#  'david.steiner@enron.com']
# 0.0
#
# GROUND TRUTH:  ['chris.lambie@enron.com']
# SUGGESTION:  ['cheryl.runge@powerpool.ab.ca' 'jagtar.tatla@powerpool.ab.ca'
#  'rob.milnthorp@enron.com' 'john.postlethwaite@enron.com'
#  'sanjeev.khanna@enron.com' 'tyler.seminuk@enron.com'
#  'angela.mcculloch@enron.com' 'kimberly.hillis@enron.com'
#  'nella.cappelletto@enron.com' 'stephanie.sever@enron.com']
# 0.0
#
# GROUND TRUTH:  ['christine_engstrom@fanniemae.com']
# SUGGESTION:  ['tim.belden@enron.com' 'janet.dietrich@enron.com'
#  'info@evans-automation.com' 'smith.day@enron.com'
#  'lance.cunningham@enron.com' 'charles.yeung@enron.com'
#  'doug.gilbert-smith@enron.com' 'mike.carson@enron.com'
#  'michelle.parks@enron.com' 'clint.dean@enron.com']
# 0.0
#
# GROUND TRUTH:  ['nancy.hetrick@enron.com']
# SUGGESTION:  ['nancy.hetrick@enron.com' 'jeff.dasovich@enron.com'
#  'david.w.delainey@enron.com' 'sarah.novosel@enron.com'
#  'j..noske@enron.com' 'donna.fulton@enron.com' 'john.lavorato@enron.com'
#  'rob.bradley@enron.com' 'jeff.keeler@enron.com' 'vicki.sharp@enron.com']
# 1.0
#
# GROUND TRUTH:  ['paul.kaufman@enron.com', 'alan.comnes@enron.com']
# SUGGESTION:  ['alan.comnes@enron.com' 'paul.kaufman@enron.com'
#  'steve.montovano@enron.com' 'janel.guerrero@enron.com'
#  'robert.frank@enron.com' 'john.shelk@enron.com' 'karen.denne@enron.com'
#  'mark.palmer@enron.com' 'joe.hartsoe@enron.com' 'ginger.dernehl@enron.com']
# 1.0
#
# GROUND TRUTH:  ['vicki.sharp@enron.com', 'jennifer.thome@enron.com']
# SUGGESTION:  ['vicki.sharp@enron.com' 'jennifer.thome@enron.com'
#  'paul.kaufman@enron.com' 'richard.shapiro@enron.com'
#  'janet.dietrich@enron.com' 'l..nicolay@enron.com' 'm..landwehr@enron.com'
#  'joe.connor@enron.com' 'ban.sharma@enron.com'
#  'elizabeth.linnell@enron.com']
# 1.0
#
# GROUND TRUTH:  ['william.kendrick@enron.com', 'jschmidt@ensr.com', 'kevin.hyatt@enron.com', 'gina.taylor@enron.com', 'stephen.veatch@enron.com', 'randy.rice@enron.com', 'louis.soldano@enron.com', 'joe.hartsoe@enron.com', 'eric.gadd@enron.com', 'john.shafer@enron.com', 'mike.riedel@enron.com', 'doug.cebryk@enron.com']
# SUGGESTION:  ['john.shafer@enron.com' 'mike.riedel@enron.com' 'stephen.veatch@enron.com'
#  'joe.hartsoe@enron.com' 'kevin.hyatt@enron.com' 'randy.rice@enron.com'
#  'louis.soldano@enron.com' 'doug.cebryk@enron.com'
#  'william.kendrick@enron.com' 'gina.taylor@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com']
# 1.0
#
# GROUND TRUTH:  ['james.d.steffes@enron.com']
# SUGGESTION:  ['james.d.steffes@enron.com' 'richard.shapiro@enron.com'
#  'harry.kingerski@enron.com' 'mday@gmssr.com' 'mark.palmer@enron.com'
#  'jennifer.rudolph@enron.com' 'mike.smith@enron.com'
#  'robert.neustaedter@enron.com' 'lisa.mellencamp@enron.com'
#  'don.black@enron.com']
# 1.0
#
# GROUND TRUTH:  ['susan.mara@enron.com', 'suzanne.calcagno@enron.com', 'don.black@enron.com', 'phillip.k.ellen@enron.com', 'donna.fulton@enron.com', 'l..gay@enron.com', 'mark.courtney@enron.com', 'paul.kaufman@enron.com', 'ed.mcmichael@enron.com', 'frank.ermis@enron.com', 'james.d.steffes@enron.com', 'tori.kuykendall@enron.com', 'jane.tholt@enron.com', 'robert.superty@enron.com', 'patti.sullivan@enron.com', 'stephanie.miller@enron.com', 'matt.smith@enron.com', 'l..nicolay@enron.com', 'barry.tycholiz@enron.com', 'jeff.dasovich@enron.com', 'leslie.lawner@enron.com', 'p..hewitt@enron.com', 'mike.grigsby@enron.com', 'kristann.shireman@enron.com', 'roger.ponce@enron.com', 'keith.holst@enron.com']
# SUGGESTION:  ['susan.mara@enron.com' 'keith.holst@enron.com' 'ed.mcmichael@enron.com'
#  'mark.courtney@enron.com' 'frank.ermis@enron.com'
#  'james.d.steffes@enron.com' 'barry.tycholiz@enron.com'
#  'robert.superty@enron.com' 'patti.sullivan@enron.com'
#  'phillip.k.ellen@enron.com']
# 1.0
#
# GROUND TRUTH:  ['joe.capasso@enron.com', 'jeffrey.miller@enron.com', 'joe.errigo@enron.com', 'eric.saibi@enron.com', 'steve.olinde@enron.com', 'l..day@enron.com', 'alexander.mcelreath@enron.com']
# SUGGESTION:  ['joe.capasso@enron.com' 'l..day@enron.com' 'samuel.schott@enron.com'
#  'claudia.guerra@enron.com' 'amy.fitzpatrick@enron.com'
#  'william.crooks@enron.com' 'marie.newhouse@enron.com'
#  'portland.shift@enron.com' 'michael.eiben@enron.com'
#  'thane.twiggs@enron.com']
# 0.285714285714
#
# GROUND TRUTH:  ['john.llodra@enron.com', 'dana.davis@enron.com', 'a..allen@enron.com', 'genia.fitzgerald@enron.com', 'm..grace@enron.com', 'ann.murphy@enron.com', 'andrea.dahlke@enron.com', 'paul.choi@enron.com', 'travis.mccullough@enron.com', 'h..moore@enron.com', 'matt.lorenz@enron.com', 'veronica.gonzalez@enron.com', 'tracy.ngo@enron.com', 'beau.ratliff@enron.com', 'kimberly.hundl@enron.com', 'marcus.nettelton@enron.com', 'lisa.brown@enron.com', 'stewart.rosman@enron.com', 'gerald.gilbert@enron.com', 'justin.laverell@enron.com', 'doug.gilbert-smith@enron.com', 'l..nicolay@enron.com', 'peter.makkai@enron.com', 'todd.decook@enron.com', 'alton.jackson@enron.com', 'leslie.hansen@enron.com', 'amy.clemons@enron.com', 'gautam.gupta@enron.com', 'joe.gordon@enron.com', 'paul.schiavone@enron.com', 'mark.confer@enron.com', 'tom.may@enron.com', 'larry.f.campbell@enron.com', 'clayton.vernon@enron.com', 'wayne.vinson@enron.com', 'm..forney@enron.com', 'lloyd.will@enron.com', 'larry.jester@enron.com', 'stacey.w.white@enron.com', 'steve.olinde@enron.com', 'alex.wong@enron.com', 'anna.santucci@enron.com', 'mark.symms@enron.com', 'kimberly.indelicato@enron.com', 'jason.williams@enron.com', 'jeffrey.miller@enron.com', 'kay.mann@enron.com', 's..landry@enron.com', 'mark.fischer@enron.com', 'lester.rawson@enron.com', 'bill.williams@enron.com', 'robert.benson@enron.com', 'clint.dean@enron.com', 'george.wood@enron.com', 'michael.jacobson@enron.com', 'karen.o', 'day@enron.com', 'rudy.acevedo@enron.com', 'leslie.reeves@enron.com', 'juan.padron@enron.com', 'g.kelly@enron.com', 'kate.symes@enron.com', 'elizabeth.sager@enron.com', 'm..driscoll@enron.com', 'maria.valdes@enron.com', 'howard.marshall@enron.com', 'monika.causholli@enron.com', 'l..day@enron.com', 'e..kelly@enron.com', 'bill.rust@enron.com', 'casey.evans@enron.com', 'steve.c.hall@enron.com', 'david.ryan@enron.com', 'larry.valderrama@enron.com', 'tom.alonso@enron.com', 'don.baughman@enron.com', 'joe.errigo@enron.com', 'matt.motley@enron.com', 'kerri.thompson@enron.com', 'paul.radous@enron.com', 'wendy.conwell@enron.com', 'chris.lenartowicz@enron.com', 'kevin.m.presto@enron.com', 'stanley.cocke@enron.com', 'erik.serio@enron.com', 'jason.choate@enron.com', 'karen.lambert@enron.com', 'ryan.slinger@enron.com', 'kayne.coulter@enron.com', 'stephanie.piwetz@enron.com', 'paul.sims@enron.com', 'harlan.murphy@enron.com', 'brant.reves@enron.com', 'russell.ballato@enron.com', 'patrick.hanse@enron.com', 'fran.chang@enron.com', 'mitch.robinson@enron.com', 'jeff.king@enron.com', 'lex.carroll@enron.com', 'david.fairley@enron.com', 'geir.solberg@enron.com', 'evelyn.metoyer@enron.com', 'narsimha.misra@enron.com', 'joe.quenet@enron.com', 'roderick.nelson@enron.com', 's..theriot@enron.com', 'john.malowney@enron.com', 'k..ratnala@enron.com', 'juan.hernandez@enron.com', 'robert.badeer@enron.com', 'madhup.kumar@enron.com', 'paul.lewis@enron.com', 'holden.salisbury@enron.com', 'j..broderick@enron.com', 'd..baughman@enron.com', 'v..porter@enron.com', 'mike.curry@enron.com', 'doug.sewell@enron.com', 'joseph.piotrowski@enron.com', 'gretchen.lotz@enron.com', 'benjamin.rogers@enron.com', 'sean.crandall@enron.com', 'diana.scholtes@enron.com', 'terri.clynes@enron.com', 'tom.moran@enron.com', 'richard.broussard@enron.com', 'dean.laurent@enron.com', 'vivien.pham@enron.com', 'eric.saibi@enron.com', 'lisa.burnett@enron.com', 'oscar.dalton@enron.com', 'hai.chen@enron.com', 'joe.stepenovitch@enron.com', 'kevin.cline@enron.com', 'robert.stalford@enron.com', 'paul.d.thomas@enron.com', 'edward.sacks@enron.com', 'janelle.scheuer@enron.com', 'david.portz@enron.com', 'r..brackett@enron.com', 'tanya.rohauer@enron.com', 'phillip.platter@enron.com', 'john.kinser@enron.com', 'l..garcia@enron.com', 'mike.swerzbin@enron.com', 'carol.st.@enron.com', 'michael.etringer@enron.com', 'mike.carson@enron.com', 'andy.pace@enron.com', 'christian.yoder@enron.com', 'cara.semperger@enron.com', 'keith.comeaux@enron.com', 'russell.diamond@enron.com', 'bil ...
# SUGGESTION:  ['h..foster@enron.com' 'casey.evans@enron.com' 'l..day@enron.com'
#  'amy.clemons@enron.com' 'howard.marshall@enron.com'
#  'maria.valdes@enron.com' 'm..driscoll@enron.com'
#  'elizabeth.sager@enron.com' 'vivien.pham@enron.com' 'g.kelly@enron.com']
# 1.0
#
# GROUND TRUTH:  ['tk.lohman@enron.com', 'tony.pryor@enron.com', 'michelle.lokay@enron.com', 'glen.hass@enron.com', 'lee.huber@enron.com', 'jan.moore@enron.com', 'steven.harris@enron.com', 'lindy.donoho@enron.com', 'kimberly.watson@enron.com', 'pallavi.goradia@enron.com', 'lorraine.lindberg@enron.com']
# SUGGESTION:  ['tk.lohman@enron.com' 'jan.moore@enron.com' 'steven.harris@enron.com'
#  'lindy.donoho@enron.com' 'pallavi.goradia@enron.com'
#  'michelle.lokay@enron.com' 'glen.hass@enron.com'
#  'lorraine.lindberg@enron.com' 'kimberly.watson@enron.com'
#  'gabriel.chavez@enron.com']
# 0.9
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com' 'tina.rode@enron.com' 'robert.benson@enron.com'
#  'shirley.tijerina@enron.com' 'laura.harder@enron.com'
#  'thomas.a.martin@enron.com' 'liz.taylor@enron.com' 'ina.rangel@enron.com'
#  'sue.ford@enron.com' 'joseph.deffner@enron.com']
# 1.0
#
# GROUND TRUTH:  ['margaret.allen@enron.com']
# SUGGESTION:  ['jbennett@gmssr.com' 'l..nicolay@enron.com' 'ray.alvarez@enron.com'
#  'richard.shapiro@enron.com' 'linda.robertson@enron.com'
#  'donna.fulton@enron.com' 'rob.bradley@enron.com'
#  'dennis.benevides@enron.com' 'gfoster@antigenics.com' 'j..noske@enron.com']
# 0.0
#
# GROUND TRUTH:  ['bradley.holmes@enron.com', 'donna.scott@enron.com', 'rick.dietz@enron.com', 'steven.january@enron.com', 'lynn.blair@enron.com', 'shelley.corman@enron.com', 'sheila.nacey@enron.com', 'mike.bryant@enron.com']
# SUGGESTION:  ['rick.dietz@enron.com' 'shelley.corman@enron.com' 'sheila.nacey@enron.com'
#  'donna.scott@enron.com' 'steven.january@enron.com'
#  'bradley.holmes@enron.com' 'lynn.blair@enron.com'
#  'terry.kowalke@enron.com' 'raetta.zadow@enron.com'
#  'gerry.medeles@enron.com']
# 0.875
#
# GROUND TRUTH:  ['sara.shackleton@enron.com']
# SUGGESTION:  ['sara.shackleton@enron.com' 'tana.jones@enron.com' 'carol.st.@enron.com'
#  'halnromm@hotmail.com' 'pinto.leite@enron.com' 'brent.hendry@enron.com'
#  'greg.piper@enron.com' 'mary.cook@enron.com' 'marie.heard@enron.com'
#  'h..moore@enron.com']
# 1.0
#
# GROUND TRUTH:  ['juan.hernandez@enron.com']
# SUGGESTION:  ['juan.hernandez@enron.com' 'jeff.dasovich@enron.com'
#  'robert.benson@enron.com' 'steven.j.kean@enron.com'
#  'mark.mcconnell@enron.com' 'jforney@enron.com' 'jshankm@enron.com'
#  'mark.whitt@enron.com' 'richard.shapiro@enron.com' 'jderric@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jean.ryall@enron.com']
# SUGGESTION:  ['jean.ryall@enron.com' 'alan.comnes@enron.com' 'harry.kingerski@enron.com'
#  'paul.kaufman@enron.com' 'janine.migden@enron.com' 'w..cantrell@enron.com'
#  'leslie.lawner@enron.com' 'lamar.frazier@enron.com'
#  'rob.bradley@enron.com' 'linda.robertson@enron.com']
# 1.0
#
# GROUND TRUTH:  ['howard.fromer@enron.com', 'geriann.warner@enron.com', 'susan.mara@enron.com', 'frank.rishe@enron.com', 'patrick.keene@enron.com', 'mccubbin', '.', 'sandra@enron.com', 'jean.ryall@enron.com', 'bill.moore@enron.com', 'kerry.stroup@enron.com', 'elizabeth.linnell@enron.com', 'paul.kaufman@enron.com', 'a..hueter@enron.com', 'robert.neustaedter@enron.com', 'l..petrochko@enron.com', 'm..landwehr@enron.com', 'richard.shapiro@enron.com', 'chauncey.hood@enron.com', 'janine.migden@enron.com', 'steve.montovano@enron.com', 'laurie.knight@enron.com', 'robert.hemstock@enron.com', 'roy.boston@enron.com', 'alan.comnes@enron.com', 'gloria.ogenyi@enron.com', 'barry.moore@enron.com', 'aleck.dadson@enron.com', 'jeff.dasovich@enron.com', 'harry.kingerski@enron.com', 'kathleen.sullivan@enron.com', 'chapman', '.', 'tom@enron.com', 'marchris.robinson@enron.com', 'james.d.steffes@enron.com', 'daniel.allegretti@enron.com', 'akin', '.', 'lysa@enron.com', 'joe.allen@enron.com']
# SUGGESTION:  ['chauncey.hood@enron.com' 'tom@enron.com' 'robert.hemstock@enron.com'
#  'steve.montovano@enron.com' 'janine.migden@enron.com'
#  'joe.allen@enron.com' 'lysa@enron.com' 'richard.shapiro@enron.com'
#  'm..landwehr@enron.com' 'robert.neustaedter@enron.com']
# 1.0
#
# GROUND TRUTH:  ['beth.jenkins@enron.com']
# SUGGESTION:  ['beth.jenkins@enron.com' 'kate.joslyn@enron.com' 'tuckiejeff@hotmail.com'
#  'ackertdm@yahoo.com' 'peggy.hedstrom@enron.com' 'kathy.reeves@enron.com'
#  'greg.mann@enron.com' 'laura.scott@enron.com' 'caroline.abramo@enron.com'
#  'adam.bayer@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com' 'larry.izzo@enron.com' 'chuck.ames@enron.com'
#  'robert.jones@enron.com' 'rebecca.carter@enron.com'
#  'richard.causey@enron.com' 'travis.mccullough@enron.com'
#  'sanjay.bhatnagar@enron.com' 'george.mcclellan@enron.com'
#  'loretta.brelsford@enron.com']
# 1.0
#
# GROUND TRUTH:  ['klyn@pdq.net']
# SUGGESTION:  ['klyn@pdq.net' 'kay.quigley@enron.com' 'siva66@msn.com'
#  'mike.maggi@enron.com' 'bobby.pritchard@enron.com' 'frthis@aol.com'
#  'john.arnold@enron.com' 'eric.groves@enron.com' 'wolphguy@aol.com'
#  'bwdunlavy@yahoo.com']
# 1.0
#
# GROUND TRUTH:  ['christie.patrick@enron.com']
# SUGGESTION:  ['christie.patrick@enron.com' 'liz.mendiola@travelpark.com'
#  'phillip.k.ellen@enron.com' 'darla.saucier@enron.com'
#  'david.kowalczyk@enron.com' 'john.sherriff@enron.com'
#  'laurie.ellis@enron.com' 'l..nicolay@enron.com' 'jef070@cs.com'
#  'c..james@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['allan.ford@enron.com' 'john.arnold@enron.com' 'kimberly.hillis@enron.com'
#  'andy.zipper@enron.com' 'barbara.hooks@enron.com'
#  'cathy.phillips@enron.com' 'sally.beck@enron.com'
#  'george.mcclellan@enron.com' 'mary.solmonson@enron.com'
#  'travis.mccullough@enron.com']
# 0.0
#
# GROUND TRUTH:  ['no.address@enron.com', 'donald.petersen@enron.com', 'leslie.lawner@enron.com']
# SUGGESTION:  ['leslie.lawner@enron.com' 'mike.grigsby@enron.com'
#  'james.d.steffes@enron.com' 'richard.b.sanders@enron.com'
#  'l..nicolay@enron.com' 'gil.muhl@enron.com' 'stephanie.miller@enron.com'
#  'barry.tycholiz@enron.com' 'zelda.paschal@enron.com'
#  'donna.greif@enron.com']
# 0.333333333333
#
# GROUND TRUTH:  ['bwdunlavy@yahoo.com', 'jramirez@othon.com', 'martier@cpchem.com', 'frthis@aol.com', 'siva66@mail.ev1.net', 'klyn@pdq.net', 'ras1119@hotmail.com', 'wolphguy@aol.com', 'markm@cajunusa.com']
# SUGGESTION:  ['markm@cajunusa.com' 'klyn@pdq.net' 'bwdunlavy@yahoo.com'
#  'ras1119@hotmail.com' 'siva66@mail.ev1.net' 'wolphguy@aol.com'
#  'frthis@aol.com' 'jramirez@othon.com' 'martier@cpchem.com'
#  'kay.quigley@enron.com']
# 1.0
#
# GROUND TRUTH:  ['stacy.dickson@enron.com', 'jason.williams@enron.com', 'kim.ward@enron.com']
# SUGGESTION:  ['kim.ward@enron.com' 'jeff.dasovich@enron.com' 'laura.luce@enron.com'
#  'mark.whitt@enron.com' 'mike.jefferies@enron.com' 'paul.lucci@enron.com'
#  'mike.grigsby@enron.com' 'mbaldwin@igservice.com' 'eric.le@enron.com'
#  'mara.bronstein@enron.com']
# 0.333333333333
#
# GROUND TRUTH:  ['j..noske@enron.com']
# SUGGESTION:  ['j..noske@enron.com' 'alan.comnes@enron.com' 'w..cantrell@enron.com'
#  'diann.huddleson@enron.com' 'karen.denne@enron.com'
#  'ray.alvarez@enron.com' 'richard.shapiro@enron.com' 'jean.ryall@enron.com'
#  'jsteffe@enron.com' 'andy.rodriquez@enron.com']
# 1.0
#
# GROUND TRUTH:  ['homb1@pdq.net', 'siva66@mail.ev1.net', 'klyn@pdq.net', 'ras1119@hotmail.com', 'wolphguy@aol.com', 'markm@cajunusa.com']
# SUGGESTION:  ['wolphguy@aol.com' 'klyn@pdq.net' 'ras1119@hotmail.com'
#  'markm@cajunusa.com' 'siva66@msn.com' 'jeff_smith@afcc.com'
#  'johnsogc@bp.com' 'kiske@enron.com' 'dutch_quigley@yahoo.com'
#  'john.arnold@enron.com']
# 0.666666666667
#
# GROUND TRUTH:  ['thomas.lowell@enron.com']
# SUGGESTION:  ['eloy.escobar@enron.com' 'rogers.herndon@enron.com'
#  'shawna.johnson@enron.com' 'melba.lozano@enron.com'
#  'david.dupre@enron.com' 'eric.thode@enron.com' 'janelle.scheuer@enron.com'
#  'john.lavorato@enron.com' 'tamara.black@enron.com'
#  'airam.arteaga@enron.com']
# 0.0
#
# GROUND TRUTH:  ['no.address@enron.com', 'susan.mara@enron.com']
# SUGGESTION:  ['susan.mara@enron.com' 'no.address@enron.com' 'alan.comnes@enron.com'
#  'karen.denne@enron.com' 'lamar.frazier@enron.com'
#  'janet.dietrich@enron.com' 'marty.sunde@enron.com' 'vicki.sharp@enron.com'
#  'james.lewis@enron.com' 'kathy.dodgen@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rogers.herndon@enron.com']
# SUGGESTION:  ['rogers.herndon@enron.com' 'louise.kitchen@enron.com'
#  'pearce.hammond@enron.com' 'charles.yeung@enron.com'
#  'richard.shapiro@enron.com' 'james.d.steffes@enron.com'
#  'wes.colwell@enron.com' 'ben.jacoby@enron.com' 'michelle.parks@enron.com'
#  'jay.webb@enron.com']
# 1.0
#
# GROUND TRUTH:  ['alan.chen@enron.com', 'm..grace@enron.com', 'madhup.kumar@enron.com']
# SUGGESTION:  ['m..grace@enron.com' 'lloyd.will@enron.com' 'doug.gilbert-smith@enron.com'
#  'jeffrey.miller@enron.com' 'alexander.mcelreath@enron.com'
#  'deolande@srpnet.com' 'juan.padron@enron.com' 'jae.black@enron.com'
#  'sashim@yahoo.com' 'william.crooks@enron.com']
# 0.333333333333
#
# GROUND TRUTH:  ['jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com']
# 1.0
#
# GROUND TRUTH:  ['christine_engstrom@fanniemae.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'w.duran@enron.com'
#  'doug.gilbert-smith@enron.com' 'j..broderick@enron.com'
#  'alan.comnes@enron.com' 'john.cummings@enron.com' 'smith.day@enron.com'
#  'jim.meyn@enron.com' 'lance.cunningham@enron.com' 'john.llodra@enron.com']
# 0.0
#
# GROUND TRUTH:  ['kim.ward@enron.com', 'jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'kim.ward@enron.com' 'mike.grigsby@enron.com'
#  'paul.lucci@enron.com' 'mark.whitt@enron.com' 'stacy.dickson@enron.com'
#  'mbaldwin@igservice.com' 'darren.vanek@enron.com'
#  'david.w.delainey@enron.com' 'phil.polsky@enron.com']
# 1.0
#
# GROUND TRUTH:  ['kim.ward@enron.com', 'jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'kim.ward@enron.com' 'mike.grigsby@enron.com'
#  'paul.lucci@enron.com' 'mark.whitt@enron.com' 'stacy.dickson@enron.com'
#  'mbaldwin@igservice.com' 'darren.vanek@enron.com'
#  'david.w.delainey@enron.com' 'phil.polsky@enron.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com', 'susan.mara@enron.com', 'richard.shapiro@enron.com', 'paul.kaufman@enron.com', 'jeff.dasovich@enron.com']
# SUGGESTION:  ['susan.mara@enron.com' 'no.address@enron.com' 'richard.shapiro@enron.com'
#  'jeff.dasovich@enron.com' 'paul.kaufman@enron.com'
#  'michael.tribolet@enron.com' 'kathy.dodgen@enron.com'
#  'robert.williams@enron.com' 'vicki.sharp@enron.com'
#  'james.lewis@enron.com']
# 1.0
#
# GROUND TRUTH:  ['juan.hernandez@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'e..haedicke@enron.com'
#  'theresa.staab@enron.com' 'harry.arora@enron.com'
#  'shelley.corman@enron.com' 'whalley@enron.com' 'lcampbel@enron.com'
#  'jderric@enron.com' 'steven.j.kean@enron.com' 'richard.shapiro@enron.com']
# 0.0
#
# GROUND TRUTH:  ['bryan.gottfredson@enron.com']
# SUGGESTION:  ['bryan.gottfredson@enron.com' 'no.address@enron.com'
#  'charles.yeung@enron.com' 'tom.briggs@enron.com' 'j..noske@enron.com'
#  'susan.lindberg@enron.com' 'kimberly.hillis@enron.com'
#  'lara.leibman@enron.com' 'ray.alvarez@enron.com' 'chris.stokley@enron.com']
# 1.0
#
# GROUND TRUTH:  ['hduncan@caem.org', 'j..noske@enron.com']
# SUGGESTION:  ['j..noske@enron.com' 'roy.boston@enron.com' 'richard.shapiro@enron.com'
#  'w..cantrell@enron.com' 'jeff.dasovich@enron.com'
#  'steve.montovano@enron.com' 'c..williams@enron.com'
#  'lynnette.barnes@enron.com' 'jeff.keeler@enron.com'
#  'lisa.jacobson@enron.com']
# 0.5
#
# GROUND TRUTH:  ['lchurch@epsa.org', 'richard.shapiro@enron.com']
# SUGGESTION:  ['richard.shapiro@enron.com' 'jeff.dasovich@enron.com'
#  'bryan.gottfredson@enron.com' 'paul.kaufman@enron.com'
#  'steve.walton@enron.com' 'wanda.curry@enron.com' 'j..noske@enron.com'
#  'm..landwehr@enron.com' 'robert.neustaedter@enron.com'
#  'rob.bradley@enron.com']
# 0.5
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'jeff.dasovich@enron.com'
#  'ginger.dernehl@enron.com' 'james.d.steffes@enron.com'
#  'linda.robertson@enron.com' 'maria.arefieva@enron.com'
#  'bruno.gaillard@enron.com' 'bill.moore@enron.com'
#  'rita.hartfield@enron.com' 'paul.kaufman@enron.com']
# 1.0
#
# GROUND TRUTH:  ['r..barker@enron.com']
# SUGGESTION:  ['r..barker@enron.com' 'chris.lambie@enron.com' 'greg.mann@enron.com'
#  'geri.greenall@elpaso.com' 'tuckiejeff@hotmail.com'
#  'kimberly.bates@enron.com' 'jennifer.fraser@enron.com'
#  'lucy.ortiz@enron.com' 'melba.lozano@enron.com' 'lisa.mcisaac@enron.com']
# 1.0
#
# GROUND TRUTH:  ['michael.roan@enron.com', 'donna.fulton@enron.com', 'janine.migden@enron.com']
# SUGGESTION:  ['michael.roan@enron.com' 'donna.fulton@enron.com'
#  'janine.migden@enron.com' 'l..nicolay@enron.com' 'susan.mara@enron.com'
#  'w..cantrell@enron.com' 'dwatkiss@bracepatt.com'
#  'richard.b.sanders@enron.com' 'linda.robertson@enron.com'
#  'jeff.keeler@enron.com']
# 1.0
#
# GROUND TRUTH:  ['zwharton@dawray.com']
# SUGGESTION:  ['zwharton@dawray.com' 'hunter.s.shively@enron.com'
#  'bryant.frihart@enron.com' 'james.simpson@enron.com'
#  'jeffrey.gossett@enron.com' 'email@lisc.net' 'jason.williams@enron.com'
#  'william.kasemervisz@enron.com' 'rob@ramind.com'
#  'andrew.h.lewis@enron.com']
# 1.0
#
# GROUND TRUTH:  ['barry.tycholiz@enron.com']
# SUGGESTION:  ['barry.tycholiz@enron.com' 'gerald.nemec@enron.com'
#  'tyrell.harrison@enron.com' 'paul.lucci@enron.com' 'kcrisa@apex2000.net'
#  'phillip.k.ellen@enron.com' 'stephanie.miller@enron.com'
#  'joan.quick@enron.com' 'eric.moon@enron.com' 'chris.hilgert@enron.com']
# 1.0
#
# GROUND TRUTH:  ['susan_m_scott@hotmail.com', 'moshuffle@hotmail.com']
# SUGGESTION:  ['susan.scott@enron.com' 'tom.may@enron.com' 'jeffrey.wilson@enron.com'
#  'lisa.gillette@enron.com' 'jeffrey.keenan@enron.com'
#  'mathew.gimble@enron.com' 'lindy.donoho@enron.com'
#  'joe.stepenovitch@enron.com' 'daniel.allegretti@enron.com'
#  'george.wood@enron.com']
# 0.0
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'paula.rieker@enron.com'
#  'jeff.skilling@enron.com' 'jeff.dasovich@enron.com'
#  'christi.nicolay@enron.com' 'meredith.philipp@enron.com'
#  'm..schmidt@enron.com' 'kenneth.lay@enron.com' 'rob.bradley@enron.com'
#  'james.d.steffes@enron.com']
# 1.0
#
# GROUND TRUTH:  ['ted.murphy@enron.com', 'mike.jordan@enron.com', 's..bradford@enron.com', 'beth.perlman@enron.com', 'beth.apollo@enron.com', 'r..brackett@enron.com', 'david.port@enron.com', 'stacey.w.white@enron.com', 'rick.buy@enron.com', 'steve.stocker@enron.com', 'shona.wilson@enron.com', 'mark.pickering@enron.com', 'wanda.curry@enron.com', 'c..gossett@enron.com', 'greg.piper@enron.com', 'tom.victorio@enron.com']
# SUGGESTION:  ['rick.buy@enron.com' 'wanda.curry@enron.com' 'tom.victorio@enron.com'
#  's..bradford@enron.com' 'mark.pickering@enron.com' 'beth.apollo@enron.com'
#  'greg.piper@enron.com' 'c..gossett@enron.com' 'beth.perlman@enron.com'
#  'r..brackett@enron.com']
# 1.0
#
# GROUND TRUTH:  ['mike.carson@enron.com', 'dana.davis@enron.com', 'j..broderick@enron.com', 'doug.gilbert-smith@enron.com', 'fletcher.j.sturm@enron.com', 'jeff.king@enron.com', 'robert.benson@enron.com']
# SUGGESTION:  ['robert.benson@enron.com' 'dana.davis@enron.com' 'j..broderick@enron.com'
#  'doug.gilbert-smith@enron.com' 'mike.carson@enron.com'
#  'fletcher.j.sturm@enron.com' 'jeff.king@enron.com' 'tim.belden@enron.com'
#  'rogers.herndon@enron.com' 'john.llodra@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jeffu192@cs.com', 'jerry.spottswood@compaq.com', 'ty.servello@oag.state.tx.us', 'johnsogc@bp.com', 'andy_reynolds@panda-law.com', 'jeff_smith@afcc.com', 'michael.deluke@us.pwcglobal.com', 'b_sting91@excite.com', 'dg_ski@email.msn.com', 'kiske@enron.com', 'klyn@pdq.net', 'mcurrie@tcta.org', 'chris.kiske@arbitron.com', 'ckiske@austin.rr.com']
# SUGGESTION:  ['jeffu192@cs.com' 'klyn@pdq.net' 'kay.quigley@enron.com' 'siva66@msn.com'
#  'john.arnold@enron.com' 'pnpatel@tecoenergy.com' 'sherry.dawson@enron.com'
#  'wolphguy@aol.com' 'kori.loibl@enron.com' 'frthis@aol.com']
# 0.2
#
# GROUND TRUTH:  ['todd.hall@enron.com', 'liz.taylor@enron.com', 'l..nowlan@enron.com', 'kimberly.hillis@enron.com', 'hal.mckinney@enron.com', 'm.hall@enron.com', 'john.allison@enron.com', 'c..gossett@enron.com', 'ted.murphy@enron.com', 'beth.apollo@enron.com', 'chris.abel@enron.com', 'sally.beck@enron.com', 'cassi.wallace@enron.com', 'bjorn.hagelmann@enron.com', 'kenneth.thibodeaux@enron.com', 'frank.hayden@enron.com', 'cassandra.schultz@enron.com', 'david.port@enron.com', 'tammie.schoppe@enron.com', 'john.swinney@enron.com', 'william.kelly@enron.com', 'rick.buy@enron.com', 'louise.kitchen@enron.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'cassi.wallace@enron.com'
#  'liz.taylor@enron.com' 'l..nowlan@enron.com' 'kimberly.hillis@enron.com'
#  'hal.mckinney@enron.com' 'm.hall@enron.com' 'john.allison@enron.com'
#  'c..gossett@enron.com' 'ted.murphy@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jmwatson@tecoenergy.com', 'erik.serio@enron.com']
# SUGGESTION:  ['erik.serio@enron.com' 'jmwatson@tecoenergy.com' 'madhup.kumar@enron.com'
#  'm..grace@enron.com' 'mpatterson@ercot.com'
#  'alexander.mcelreath@enron.com' 'phillips.george@enron.com'
#  'iz.wong@enron.com' 'joe.capasso@enron.com' 'jeffrey.miller@enron.com']
# 1.0
#
# GROUND TRUTH:  ['mark.palmer@enron.com', 'richard.shapiro@enron.com']
# SUGGESTION:  ['richard.shapiro@enron.com' 'mark.palmer@enron.com'
#  'jeff.dasovich@enron.com' 'steven.j.kean@enron.com'
#  'mona.petrochko@enron.com' 'ray.alvarez@enron.com'
#  'ursula.brenner@enron.com' 'no.address@enron.com'
#  'richard.b.sanders@enron.com' 'paul.kaufman@enron.com']
# 1.0
#
# GROUND TRUTH:  ['cheryl.nelson@enron.com', 'marie.heard@enron.com', 't..brogan@enron.com', 'sara.shackleton@enron.com', 'aneela.charania@enron.com']
# SUGGESTION:  ['sara.shackleton@enron.com' 'marie.heard@enron.com'
#  'cheryl.nelson@enron.com' 'aneela.charania@enron.com'
#  'theresa.brogan@enron.com' 'donna.lowry@enron.com'
#  'darren.delage@enron.com' 'ted.murphy@enron.com' 'ellen.su@enron.com'
#  's..bradford@enron.com']
# 0.8
#
# GROUND TRUTH:  ['richard.shapiro@enron.com', 'amr.ibrahim@enron.com', 'harry.kingerski@enron.com']
# SUGGESTION:  ['amr.ibrahim@enron.com' 'richard.shapiro@enron.com'
#  'harry.kingerski@enron.com' 'paul.kaufman@enron.com'
#  'dwatkiss@bracepatt.com' 'jeff.keeler@enron.com' 'charles.yeung@enron.com'
#  'robert.neustaedter@enron.com' 'rob.bradley@enron.com'
#  'eric.letke@enron.com']
# 1.0
#
# GROUND TRUTH:  ['erik.serio@enron.com']
# SUGGESTION:  ['erik.serio@enron.com' 'lloyd.will@enron.com' 'm..grace@enron.com'
#  '@enron.com' 'joe.capasso@enron.com' 'jeffrey.miller@enron.com'
#  'alexander.mcelreath@enron.com' 'keith.comeaux@enron.com'
#  'doug.gilbert-smith@enron.com' 'steve.olinde@enron.com']
# 1.0
#
# GROUND TRUTH:  ['swtgurlntx@aol.com']
# SUGGESTION:  ['john.buchanan@enron.com' 'steven.january@enron.com'
#  'gary.choquette@enron.com' 'steven.harris@enron.com'
#  'kevin.hyatt@enron.com' 'team.roswell@enron.com'
#  'helen.cummings@enron.com' 'richard.hanagriff@enron.com'
#  'steve.coash@enron.com' 'lindy.donoho@enron.com']
# 0.0
#
# GROUND TRUTH:  ['joe.capasso@enron.com', 'jeffrey.miller@enron.com', 'joe.errigo@enron.com', 'eric.saibi@enron.com', 'steve.olinde@enron.com', 'l..day@enron.com', 'alexander.mcelreath@enron.com']
# SUGGESTION:  ['joe.errigo@enron.com' 'jeffrey.miller@enron.com'
#  'alexander.mcelreath@enron.com' 'l..day@enron.com'
#  'steve.olinde@enron.com' 'eric.saibi@enron.com' 'joe.capasso@enron.com'
#  'doug.gilbert-smith@enron.com' 'erik.serio@enron.com'
#  'jmwatson@tecoenergy.com']
# 1.0
#
# GROUND TRUTH:  ['no.address@enron.com']
# SUGGESTION:  ['no.address@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jason.williams@enron.com']
# SUGGESTION:  ['jason.williams@enron.com' 'jason.wolfe@enron.com' 'rmortensen@wm.com'
#  'barry.tycholiz@enron.com' 'lbarton@hesinet.com'
#  'shance@siliconvalleypower.com' 'debra.perlingiere@enron.com'
#  'sendo@ci.pasadena.ca.us' 'jfuller@prmllp.com' 'jlb3@knauffiberglass.com']
# 1.0
#
# GROUND TRUTH:  ['robert.hemstock@enron.com']
# SUGGESTION:  ['robert.hemstock@enron.com' 'nella.cappelletto@enron.com'
#  'angela.mcculloch@enron.com' 'cheryl.runge@powerpool.ab.ca'
#  'jagtar.tatla@powerpool.ab.ca' 'rob.milnthorp@enron.com'
#  'john.postlethwaite@enron.com' 'sanjeev.khanna@enron.com'
#  'tyler.seminuk@enron.com' 'kimberly.hillis@enron.com']
# 1.0
#
# GROUND TRUTH:  ['stacy.dickson@enron.com']
# SUGGESTION:  ['stacy.dickson@enron.com' 'richard.deming@enron.com'
#  'barry.tycholiz@enron.com' 'craig.taylor@enron.com'
#  'jason.williams@enron.com' 'travis.mccullough@enron.com'
#  'lbracken@summitenergy.com' 'jason.wolfe@enron.com'
#  'belindalulu@hotmail.com' 'kelli.little@enron.com']
# 1.0
#
# GROUND TRUTH:  ['kay.quigley@enron.com']
# SUGGESTION:  ['kay.quigley@enron.com' 'jramirez@othon.com' 'homb1@pdq.net'
#  'siva66@msn.com' 'joey.taylor@enron.com' 'frthis@aol.com'
#  'dutch.quigley@enron.com' 'rs1119@aol.com' 'wolphguy@aol.com'
#  'bwdunlavy@yahoo.com']
# 1.0
#
# GROUND TRUTH:  ['jason.williams@enron.com']
# SUGGESTION:  ['jason.williams@enron.com' 'kelli.little@enron.com'
#  'stacy.dickson@enron.com' 'sara.shackleton@enron.com'
#  'mreese@cmsenergy.com' 'jan.sutherland@enron.com' 'anne.bike@enron.com'
#  'darren.vanek@enron.com' 'estrickland@mieco.com' 'darla.saucier@enron.com']
# 1.0
#
# GROUND TRUTH:  ['todd.hall@enron.com', 'liz.taylor@enron.com', 'l..nowlan@enron.com', 'kimberly.hillis@enron.com', 'hal.mckinney@enron.com', 'm.hall@enron.com', 'john.allison@enron.com', 'c..gossett@enron.com', 'ted.murphy@enron.com', 'beth.apollo@enron.com', 'chris.abel@enron.com', 'sally.beck@enron.com', 'cassi.wallace@enron.com', 'bjorn.hagelmann@enron.com', 'kenneth.thibodeaux@enron.com', 'frank.hayden@enron.com', 'cassandra.schultz@enron.com', 'david.port@enron.com', 'tammie.schoppe@enron.com', 'john.swinney@enron.com', 'william.kelly@enron.com', 'rick.buy@enron.com', 'louise.kitchen@enron.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'cassi.wallace@enron.com'
#  'liz.taylor@enron.com' 'l..nowlan@enron.com' 'kimberly.hillis@enron.com'
#  'hal.mckinney@enron.com' 'm.hall@enron.com' 'john.allison@enron.com'
#  'c..gossett@enron.com' 'ted.murphy@enron.com']
# 1.0
#
# GROUND TRUTH:  ['controllers.dl-ets@enron.com']
# SUGGESTION:  ['controllers.dl-ets@enron.com' 'beverly.miller@enron.com'
#  'gary.spraggins@enron.com' 'terry.kowalke@enron.com'
#  'bert.hernandez@enron.com' 'jesse.alvarado@enron.com'
#  'dale.ratliff@enron.com' 'bart.monden@enron.com' 'crandal.hardy@enron.com'
#  'keith.braswell@enron.com']
# 1.0
#
# GROUND TRUTH:  ['john.shafer@enron.com']
# SUGGESTION:  ['john.shafer@enron.com' 'scott.jones@enron.com' 'rick.loveless@enron.com'
#  'louis.soldano@enron.com' 'team.laguna@enron.com'
#  'donna.martens@enron.com' 'thackett@ensr.com' 'rick.cates@enron.com'
#  'rick.smith@enron.com' 'phil.lowry@enron.com']
# 1.0
#
# GROUND TRUTH:  ['joe.capasso@enron.com', 'jeffrey.miller@enron.com', 'joe.errigo@enron.com', 'eric.saibi@enron.com', 'steve.olinde@enron.com', 'l..day@enron.com', 'alexander.mcelreath@enron.com']
# SUGGESTION:  ['joe.capasso@enron.com' 'joe.errigo@enron.com' 'steve.olinde@enron.com'
#  'eric.saibi@enron.com' 'jeffrey.miller@enron.com' 'l..day@enron.com'
#  'alexander.mcelreath@enron.com' 'sashim@yahoo.com' 'm..grace@enron.com'
#  'mpatterson@ercot.com']
# 1.0
#
# ...
# SUGGESTION:  ['h..douglas@enron.com' 'n..gray@enron.com' 'travis.mccullough@enron.com'
#  'brent.hendry@enron.com' 'lisa.mellencamp@enron.com'
#  'angela.davis@enron.com' 'leslie.hansen@enron.com' 'frank.sayre@enron.com'
#  'gerald.nemec@enron.com' 'elizabeth.sager@enron.com']
# 1.0
#
# GROUND TRUTH:  ['aazccb@swbell.net']
# SUGGESTION:  ['aazccb@swbell.net' 'ina.rangel@enron.com' 'savita.puthigai@enron.com'
#  'justin.rostant@enron.com' 'john.arnold@enron.com'
#  'larry.gagliardi@enron.com' 'kevin.delafield@enron.com'
#  'adam.johnson@enron.com' 'john.wilson@enron.com' 'carl.carter@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rick.dietz@enron.com', 'shelley.corman@enron.com', 'bradley.holmes@enron.com', 'steve.january@enron.com']
# SUGGESTION:  ['shelley.corman@enron.com' 'rick.dietz@enron.com'
#  'steve.january@enron.com' 'raetta.zadow@enron.com' 'ava.garcia@enron.com'
#  'john.buchanan@enron.com' 'kimberly.watson@enron.com'
#  'steven.january@enron.com' 'tracy.minter@enron.com'
#  'lindy.donoho@enron.com']
# 0.75
#
# GROUND TRUTH:  ['chris.hyde@enron.com']
# SUGGESTION:  ['dipak.agarwalla@enron.com' 'jkidd@econone.com' 'bill.fortney@enron.com'
#  'dave.fuller@enron.com' 'j..brewer@enron.com' 'matt.sample@enform.com'
#  'askchristine@avistautilities.com' 'steven.p.south@enron.com'
#  'valerie.ridinger@alcoa.com' 'sangitad@plp.com']
# 0.0
#
# GROUND TRUTH:  ['ann.hill@enron.com']
# SUGGESTION:  ['ann.hill@enron.com' 'richard.shapiro@enron.com'
#  'kathleen.sullivan@enron.com' 'lisa.yoho@enron.com'
#  'jeff.dasovich@enron.com' 'melinda.pharms@enron.com'
#  'janel.guerrero@enron.com' 'm..landwehr@enron.com'
#  'steven.j.kean@enron.com' 'tom.briggs@enron.com']
# 1.0
#
# GROUND TRUTH:  ['s..presas@enron.com']
# SUGGESTION:  ['s..presas@enron.com' 'david.allan@enron.com' 'pete.davis@enron.com'
#  'e..carter@enron.com' 'peggy.determeyer@enron.com'
#  'avril.forster@enron.com' 'v..reed@enron.com' 'r..conner@enron.com'
#  'milagros.daetz@enron.com' 'greg.bruch@enron.com']
# 1.0
#
# GROUND TRUTH:  ['taylor@enron.com']
# SUGGESTION:  ['taylor@enron.com' 'tana.jones@enron.com' 'mark.evans@enron.com'
#  'angeline.poon@enron.com' 'nony.flores@enron.com'
#  'mark.e.taylor@enron.com' 'jane.mcbride@enron.com'
#  'sara.shackleton@enron.com' 'edmund.cooper@enron.com'
#  'john.suttle@enron.com']
# 1.0
#
# GROUND TRUTH:  ['taylor@enron.com', 'tana.jones@enron.com', 'samantha.boyd@enron.com']
# SUGGESTION:  ['tana.jones@enron.com' 'taylor@enron.com' 'samantha.boyd@enron.com'
#  'sara.shackleton@enron.com' 'susan.bailey@enron.com'
#  'paul.radous@enron.com' 'marie.heard@enron.com' 's..theriot@enron.com'
#  'roderick.nelson@enron.com' 'larry.hunter@enron.com']
# 1.0
#
# GROUND TRUTH:  ['john.buchanan@enron.com', 'gerry.medeles@enron.com', 'jo.williams@enron.com', 'terry.kowalke@enron.com', 'vernon.mercaldo@enron.com']
# SUGGESTION:  ['vernon.mercaldo@enron.com' 'john.buchanan@enron.com'
#  'terry.kowalke@enron.com' 'jo.williams@enron.com' 'raetta.zadow@enron.com'
#  'shelley.corman@enron.com' 'jean.blair@enron.com' 'larry.berger@enron.com'
#  'rick.dietz@enron.com' 'bradley.holmes@enron.com']
# 0.8
#
# GROUND TRUTH:  ['mark.palmer@enron.com', 'c..koehler@enron.com', 'brandon.wax@enron.com', 'tana.jones@enron.com', 'rex.shelby@enron.com']
# SUGGESTION:  ['tana.jones@enron.com' 'c..koehler@enron.com' 'susan.harrison@enron.com'
#  'kal.shah@enron.com' 'taylor@enron.com' 'vanessa.schulte@enron.com'
#  'michael.bridges@enron.com' 'kim.monk@enron.com' 'bob.shults@enron.com'
#  'stacy.dickson@enron.com']
# 0.4
#
# GROUND TRUTH:  ['brent.hendry@enron.com', 'tana.jones@enron.com']
# SUGGESTION:  ['brent.hendry@enron.com' 'tana.jones@enron.com' 'angela.davis@enron.com'
#  'sara.shackleton@enron.com' 'mark.greenberg@enron.com'
#  'susan.bailey@enron.com' 'samantha.boyd@enron.com'
#  'holly.keiser@enron.com' 'nita.garcia@enron.com' 'mary.cook@enron.com']
# 1.0
#
# GROUND TRUTH:  ['joanne.rozycki@enron.com']
# SUGGESTION:  ['joanne.rozycki@enron.com' 'c..koehler@enron.com'
#  'cheryl.nelson@enron.com' 'tana.jones@enron.com' 'mary.cook@enron.com'
#  'taylor@enron.com' 'marie.heard@enron.com' 'pinto.leite@enron.com'
#  'clint.freeland@enron.com' 'laurel.adams@enron.com']
# 1.0
#
# GROUND TRUTH:  ['c..williams@enron.com', 'e..haedicke@enron.com', 'richard.b.sanders@enron.com']
# SUGGESTION:  ['richard.b.sanders@enron.com' 'c..williams@enron.com'
#  'e..haedicke@enron.com' 'j.harris@enron.com' 'jordan.mintz@enron.com'
#  'cbreaux@ncsc.dni' 'tracy.foy@enron.com' 'krchoi@sk-enron.com'
#  'no.address@enron.com' 'cschwartz@velaw.com']
# 1.0
#
# GROUND TRUTH:  ['rick.loveless@enron.com', 'andrew.gieser.enronxgate@enron.com', 'john.shafer.enronxgate@enron.com', 'ralph.edwards.enronxgate@enron.com', 'brian.oeffner@enron.com', 'william.kendrick.enronxgate@enron.com', 'dee.hanson@enron.com', 'danny.quint.enronxgate@enron.com', 'mike.riedel@enron.com', 'larry.f.campbell@enron.com']
# SUGGESTION:  ['andrew.gieser.enronxgate@enron.com'
#  'william.kendrick.enronxgate@enron.com' 'danny.quint.enronxgate@enron.com'
#  'brian.oeffner@enron.com' 'ralph.edwards.enronxgate@enron.com'
#  'john.shafer.enronxgate@enron.com' 'dee.hanson@enron.com'
#  'rick.loveless@enron.com' 'mike.riedel@enron.com'
#  'larry.f.campbell@enron.com']
# 1.0
#
# GROUND TRUTH:  ['william.kendrick@enron.com', 'ruth.jensen@enron.com', 'byron.rance@enron.com', 'earl.chanley@enron.com', 'arnold.eisenstein@enron.com', 'donna.martens@enron.com', 'dan.pribble@enron.com', 'john.shafer@enron.com', 'jerry.martin@enron.com']
# SUGGESTION:  ['jerry.martin@enron.com' 'william.kendrick@enron.com'
#  'byron.rance@enron.com' 'dan.pribble@enron.com' 'john.shafer@enron.com'
#  'ruth.jensen@enron.com' 'donna.martens@enron.com' 'earl.chanley@enron.com'
#  'arnold.eisenstein@enron.com' 'kohn.roger@epamail.epa.gov']
# 1.0
#
# GROUND TRUTH:  ['center.dl-portland@enron.com']
# SUGGESTION:  ['center.dl-portland@enron.com' 'jeff.richter@enron.com'
#  'anna.mehrer@enron.com' 'kate.symes@enron.com' 'louise.kitchen@enron.com'
#  'holden.salisbury@enron.com' 'h..foster@enron.com' 'neil@enron.com'
#  'elizabeth.sager@enron.com' 'maria.houten@enron.com']
# 1.0
#
# GROUND TRUTH:  ['dan.dietrich@enron.com', 'center.dl-portland@enron.com', 'richard.b.sanders@enron.com', 'e..haedicke@enron.com']
# SUGGESTION:  ['center.dl-portland@enron.com' 'e..haedicke@enron.com'
#  'richard.b.sanders@enron.com' 'dan.dietrich@enron.com'
#  'tim.heizenrader@enron.com' 'monika.causholli@enron.com'
#  'mike.swerzbin@enron.com' 'paul.kaufman@enron.com' 'no.address@enron.com'
#  'elizabeth.sager@enron.com']
# 1.0
#
# GROUND TRUTH:  ['louise.kitchen@enron.com']
# SUGGESTION:  ['louise.kitchen@enron.com' 'gerald.nemec@enron.com'
#  'prbaillargeon@marathonoil.com' 'kelly.kimberly@enron.com'
#  'jean.mrha@enron.com' 'faith.killen@enron.com' 'gregory.adams@enron.com'
#  'cindy.olson@enron.com' 'carol.carter@enron.com' 'john.grass@enron.com']
# 1.0
#
# GROUND TRUTH:  ['morris.clark@enron.com']
# SUGGESTION:  ['pinto.leite@enron.com' 'diane.anderson@enron.com'
#  'kelly.templeton@enron.com' 'tana.jones@enron.com'
#  'cindy.richardson@enron.com' 'mklemont@bear.com'
#  'michael.garberding@enron.com' 's..theriot@enron.com'
#  'rebecca.bell@enron.com' 'ameytina@bear.com']
# 0.0
#
# GROUND TRUTH:  ['frank.hayden@enron.com']
# SUGGESTION:  ['frank.hayden@enron.com' 'rogers.herndon@enron.com' 'lloyd.will@enron.com'
#  'billy.braddock@enron.com' 'john.lavorato@enron.com'
#  'd..baughman@enron.com' 'jae.black@enron.com' 'john.suarez@enron.com'
#  'info@evans-automation.com' 'ben.jacoby@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jeaster@reliant.com']
# SUGGESTION:  ['wendy.conwell@enron.com' 'david.gorte@enron.com' 'greg.piper@enron.com'
#  'sheila.glover@enron.com' 'jeffrey.a.shankman@enron.com'
#  'mike.jordan@enron.com' 'david.crews@enron.com' 'l..carson@enron.com'
#  'joseph.deffner@enron.com' 'cfishkin@kpmg.com']
# 0.0
#
# GROUND TRUTH:  ['jason.williams@enron.com', 'steve.van@enron.com', 'julia.murray@enron.com', 'gerald.nemec@enron.com', 'travis.mccullough@enron.com', 'marie.heard@enron.com', 'david.portz@enron.com', 'morris.clark@enron.com', 'tanya.rohauer@enron.com', 'peter.keohane@enron.com', 'lech.kalembka@enron.com', 't..hodge@enron.com', 'tana.jones@enron.com', 'frank.sayre@enron.com', 'elizabeth.sager@enron.com', 'leslie.hansen@enron.com', 'angela.davis@enron.com', 'lisa.mellencamp@enron.com', 'brent.hendry@enron.com', 'alan.aronowitz@enron.com', 'paul.simons@enron.com', 'n..gray@enron.com', 'rick.antonoff@enron.com', 'peter.del@enron.com', 'c..koehler@enron.com', 'carol.st.@enron.com', 'marcus.von@enron.com', 'sara.shackleton@enron.com', 'john.viverito@enron.com', 'pinto.leite@enron.com', 'harlan.murphy@enron.com', 'h..douglas@enron.com']
# SUGGESTION:  ['h..douglas@enron.com' 'frank.sayre@enron.com' 'morris.clark@enron.com'
#  'gerald.nemec@enron.com' 'alan.aronowitz@enron.com'
#  'brent.hendry@enron.com' 'lisa.mellencamp@enron.com'
#  'angela.davis@enron.com' 'leslie.hansen@enron.com'
#  'elizabeth.sager@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jason.williams@enron.com', 'steve.van@enron.com', 'julia.murray@enron.com', 'gerald.nemec@enron.com', 'travis.mccullough@enron.com', 'marie.heard@enron.com', 'david.portz@enron.com', 'morris.clark@enron.com', 'tanya.rohauer@enron.com', 'peter.keohane@enron.com', 'lech.kalembka@enron.com', 't..hodge@enron.com', 'tana.jones@enron.com', 'frank.sayre@enron.com', 'elizabeth.sager@enron.com', 'leslie.hansen@enron.com', 'angela.davis@enron.com', 'lisa.mellencamp@enron.com', 'brent.hendry@enron.com', 'alan.aronowitz@enron.com', 'paul.simons@enron.com', 'n..gray@enron.com', 'rick.antonoff@enron.com', 'peter.del@enron.com', 's..bradford@enron.com', 'c..koehler@enron.com', 'carol.st.@enron.com', 'marcus.von@enron.com', 'sara.shackleton@enron.com', 'john.viverito@enron.com', 'louise.kitchen@enron.com', 'pinto.leite@enron.com', 'harlan.murphy@enron.com', 'h..douglas@enron.com']
# SUGGESTION:  ['h..douglas@enron.com' 'rick.antonoff@enron.com' 'paul.simons@enron.com'
#  'alan.aronowitz@enron.com' 'brent.hendry@enron.com'
#  'lisa.mellencamp@enron.com' 'angela.davis@enron.com'
#  'leslie.hansen@enron.com' 'frank.sayre@enron.com'
#  'elizabeth.sager@enron.com']
# 1.0
#
# GROUND TRUTH:  ['christina.valdez@enron.com']
# SUGGESTION:  ['christina.valdez@enron.com' 'jason.rios@enron.com'
#  'lorraine.becker@enron.com' 'kimberly.perkins@enron.com'
#  'stephanie_rodeghiero@hp.com' 'expense.report@enron.com'
#  'michael.rosen@enron.com' 'gwynn.gorsuch@enron.com' 'john.walt@enron.com'
#  'piropos@austin.rr.com']
# 1.0
#
# GROUND TRUTH:  ['john.arnold@enron.com']
# SUGGESTION:  ['john.arnold@enron.com' 'monica_padilla@city.palo-alto.ca.us'
#  'h..foster@enron.com' 'anne.bike@enron.com' 'stacy.dickson@enron.com'
#  'mara.bronstein@enron.com' 'gerald.nemec@enron.com' 'dan.hyvl@enron.com'
#  'janine.cashin@enron.com' 'tomd1966@yahoo.com']
# 1.0
#
# GROUND TRUTH:  ['marie.heard@enron.com', 't..hodge@enron.com', 'pinto.leite@enron.com', 'sharon.crawford@enron.com', 'tanya.rohauer@enron.com']
# SUGGESTION:  ['sharon.crawford@enron.com' 't..hodge@enron.com' 'marie.heard@enron.com'
#  'tanya.rohauer@enron.com' 'william.bradford@enron.com'
#  'e..haedicke@enron.com' 'jeffrey.hodge@enron.com'
#  'peggy.hedstrom@enron.com' 'eric.le@enron.com' 'mark.e.taylor@enron.com']
# 0.8
#
# GROUND TRUTH:  ['natalie.baker@enron.com']
# SUGGESTION:  ['eric.bass@enron.com' 'jim.pond@enron.com' 'shane.dobbs@fctg.com'
#  'jeffrey.gossett@enron.com' 'willie.stewart@enron.com'
#  'jayant.krishnaswamy@enron.com' 'william.kasemervisz@enron.com'
#  'shelly.jones@enron.com' 'lee.fascetti@enron.com' 'alove770@cs.com']
# 0.0
#
# GROUND TRUTH:  ['amr.ibrahim@enron.com', 'bryan.gottfredson@enron.com']
# SUGGESTION:  ['amr.ibrahim@enron.com' 'alan.comnes@enron.com' 'janet.dietrich@enron.com'
#  'l..nicolay@enron.com' 'linda.robertson@enron.com'
#  'robert.frank@enron.com' 'j..noske@enron.com' 'richard.shapiro@enron.com'
#  'robert.neustaedter@enron.com' 'rob.bradley@enron.com']
# 0.5
#
# GROUND TRUTH:  ['richard.shapiro@enron.com']
# SUGGESTION:  ['richard.shapiro@enron.com' 'mark.whitt@enron.com' 'e..haedicke@enron.com'
#  'whalley@enron.com' 'dfarmer@enron.com' 'hunter.s.shively@enron.com'
#  'shelley.corman@enron.com' 'jarnold@enron.com' 'steven.j.kean@enron.com'
#  'jeff.skilling@enron.com']
# 1.0
#
# GROUND TRUTH:  ['richard.shapiro@enron.com']
# SUGGESTION:  ['richard.shapiro@enron.com' 'jshankm@enron.com' 'fsturm@enron.com'
#  'shelley.corman@enron.com' 'rick.buy@enron.com' 'gblair@enron.com'
#  'taylor@enron.com' 'jarnold@enron.com' 'richard.b.sanders@enron.com']
# 1.0
#
# GROUND TRUTH:  ['e..haedicke@enron.com']
# SUGGESTION:  ['e..haedicke@enron.com' 'mark.whitt@enron.com' 'whalley@enron.com'
#  'steven.j.kean@enron.com' 'richard.shapiro@enron.com' 'fsturm@enron.com'
#  'barry.tycholiz@enron.com' 'kimberly.watson@enron.com'
#  'rick.buy@enron.com' 'gblair@enron.com']
# 1.0
#
# GROUND TRUTH:  ['e..haedicke@enron.com']
# SUGGESTION:  ['e..haedicke@enron.com' 'rick.buy@enron.com' 'steven.j.kean@enron.com'
#  'jarnold@enron.com' 'fsturm@enron.com' 'barry.tycholiz@enron.com'
#  'kimberly.watson@enron.com' 'mark.whitt@enron.com' 'gblair@enron.com'
#  'jeff.skilling@enron.com']
# 1.0
#
# GROUND TRUTH:  ['richard.shapiro@enron.com']
# SUGGESTION:  ['richard.shapiro@enron.com' 'steven.j.kean@enron.com'
#  'e..haedicke@enron.com' 'harry.arora@enron.com' 'robert.benson@enron.com'
#  'jderric@enron.com' 'whalley@enron.com' 'lcampbel@enron.com'
#  'don.baughman@enron.com' 'mark.whitt@enron.com']
# 1.0
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'theresa.staab@enron.com'
#  'richard.shapiro@enron.com' 'mark.whitt@enron.com'
#  'jeff.dasovich@enron.com' 'e..haedicke@enron.com' 'harry.arora@enron.com'
#  'mary.fischer@enron.com' 'robert.benson@enron.com' 'jderric@enron.com']
# 1.0
#
# GROUND TRUTH:  ['jeff.dasovich@enron.com']
# SUGGESTION:  ['jeff.dasovich@enron.com' 'richard.shapiro@enron.com'
#  'barry.tycholiz@enron.com' 'jderric@enron.com' 'mark.whitt@enron.com'
#  'robert.benson@enron.com' 'steven.j.kean@enron.com' 'lcampbel@enron.com'
#  'whalley@enron.com' 'e..haedicke@enron.com']
# 1.0
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'mark.whitt@enron.com'
#  'richard.shapiro@enron.com' 'jeff.dasovich@enron.com'
#  'e..haedicke@enron.com' 'theresa.staab@enron.com' 'harry.arora@enron.com'
#  'mary.fischer@enron.com' 'robert.benson@enron.com' 'lcampbel@enron.com']
# 1.0
#
# GROUND TRUTH:  ['steven.j.kean@enron.com']
# SUGGESTION:  ['steven.j.kean@enron.com' 'mark.whitt@enron.com' 'rick.buy@enron.com'
#  'e..haedicke@enron.com' 'shelley.corman@enron.com'
#  'hunter.s.shively@enron.com' 'richard.b.sanders@enron.com'
#  'richard.shapiro@enron.com' 'whalley@enron.com' 'gblair@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rick.buy@enron.com']
# SUGGESTION:  ['rick.buy@enron.com' 'shelley.corman@enron.com' 'mark.whitt@enron.com'
#  'steven.j.kean@enron.com' 'e..haedicke@enron.com' 'fsturm@enron.com'
#  'barry.tycholiz@enron.com' 'gblair@enron.com' 'jeff.skilling@enron.com'
#  'whalley@enron.com']
# 1.0
#
# GROUND TRUTH:  ['rick.buy@enron.com']
# SUGGESTION:  ['rick.buy@enron.com' 'jsteffe@enron.com' 'kimberly.watson@enron.com'
#  'jeff.skilling@enron.com' 'steven.j.kean@enron.com'
#  'richard.shapiro@enron.com' 'jarnold@enron.com']
# 1.0
#
# GROUND TRUTH:  ['shelley.corman@enron.com']
# SUGGESTION:  ['shelley.corman@enron.com' 'steven.j.kean@enron.com'
#  'kimberly.watson@enron.com' 'e..haedicke@enron.com' 'fsturm@enron.com'
#  'barry.tycholiz@enron.com' 'rick.buy@enron.com' 'mark.whitt@enron.com'
#  'gblair@enron.com' 'jeff.skilling@enron.com']
# 1.0

# %%
np.mean(all_mean_ap)
# Out:
# 0.3820256320861678

# %%
results.to_csv('../submission/learning_RFC_estimators_10_balanced.csv')

# %%
with io.open('../submission/cross_val_RFC_results_basic_features(same_as_paper).json', 'w', encoding='utf-8') as f:
    f.write(unicode(json.dumps(str(cross_val_results), ensure_ascii=False)))

# %% [markdown]
# ## Get NSF and NRF
# - NSF: number of messages sent by sender to this recipient, divided by all messages sent by sender
# - NRF: number of messages received from the recipient to the sender, divided by all messages received by sender

# %%
sent_to = {}
for row in training.iterrows():
    sender = row[1]['sender']
    sent_to[sender] = {}
    for mid in row[1]['mids'].split():
        recipients = training_info[training_info.mid == int(mid)]['recipients'].values[0].split()
        for recipient in recipients:
            if '@' in recipient:
                if recipient in sent_to[sender].keys():
                    sent_to[sender][recipient] += 1
                else:
                    sent_to[sender][recipient] = 1

# %%
received_from = {}
for sender in sent_to.keys():
    for recipient in sent_to[sender].keys():
        if recipient not in received_from.keys():
            received_from[recipient] = {}
        if sender not in received_from[recipient].keys():
            received_from[recipient][sender] = sent_to[sender][recipient]
        else:
            received_from[recipient][sender] += sent_to[sender][recipient]

# %%
# normalization:
for sender in sent_to.keys():
    norm = sum(sent_to[sender].values())
    for recipient in sent_to[sender].keys():
        sent_to[sender][recipient] = float(sent_to[sender][recipient])/norm

# %%
# normalization:
for recipient in received_from.keys():
    norm = sum(received_from[recipient].values())
    for sender in received_from[recipient].keys():
        received_from[recipient][sender] = float(received_from[recipient][sender])/norm

# %%
with io.open('../data/sent_to.json', 'w', encoding='utf-8') as f:
    f.write(unicode(json.dumps(sent_to, ensure_ascii=False)))
with io.open('../data/received_from.json', 'w', encoding='utf-8') as f:
    f.write(unicode(json.dumps(received_from, ensure_ascii=False)))

# %%
with io.open('../data/sent_to.json') as json_data:
    sent_to = json.load(json_data)
